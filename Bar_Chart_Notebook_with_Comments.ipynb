# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set() # эта команда устанавливает стиль диаграммы seaborn по умолчанию

# %%
# Подключение к файлу с данными
df_used_cars = pd.read_csv("https://raw.githubusercontent.com/trisha00001/EDA/main/bar_chart_data.csv")

# %%
df_used_cars
# Out:
#            Brand  Cars Listings
# 0           Audi            419
# 1            BMW            636
# 2  Mercedes-Benz            820
# 3     Mitsubishi            306
# 4        Renault            438
# 5         Toyota            509
# 6     Volkswagen            875

# %%
plt.figure(figsize = (9, 6)) #размер диаграммы
# создать столбчатую диаграмму'bar'.
plt.bar(x = df_used_cars["Brand"], #подпишем ось x
        height = df_used_cars["Cars Listings"], #подпишем ось y
        color = "midnightblue") # определим цвет
plt.xticks(rotation = 45, fontsize = 13) # повернуть и отформатировать надписи по оси x
plt.yticks(fontsize = 13) # формат шрифта y
plt.title("Объявления об автомобилях​ в зависимости от бренда", fontsize = 16, fontweight = "bold") #Формат заголовка
plt.ylabel("Количество просмотров", fontsize = 13 ) #заголовок для оси y
plt.savefig("Cars_Bar.png") # Сохраним файл
plt.show() # в зависимости от того, какую среду вы используете, без этой строки ваша диаграмма может отображаться неправильно.

# %%
plt.figure(figsize = (9, 6))
plt.barh(y = df_used_cars["Brand"], #подпись y
        width = df_used_cars["Cars Listings"], #подпись x
        color = "midnightblue")
plt.xticks( fontsize = 13)
plt.yticks( fontsize = 13)
plt.title("Объявления об автомобилях​ в зависимости от бренда", fontsize = 16, fontweight = "bold")
plt.xlabel("Количество просмотров", fontsize = 13 )
plt.tight_layout()#tight_layout автоматически настраивает параметры подграфика таким образом, чтобы подграфик(и) вписывался в область рисунка
plt.savefig("Cars_Bar.png")
plt.show()

# %%
# load data. Number of cars based on their engine fuel types. Four engine fuel types in total : Diesel, Gas, Petrol and Other.
df_fuel_engine_type = pd.read_csv("https://raw.githubusercontent.com/trisha00001/EDA/main/pie_chart_data.csv")

# %%
df_fuel_engine_type
# Out:
#   Engine Fuel Type  Number of Cars
# 0           Diesel            2019
# 1              Gas             613
# 2            Other             154
# 3           Petrol            1559

# %%
# Установите цветовой цикл matplotlib, используя палитру seaborn
sns.set_palette('colorblind')

# %%
# Метки добавляются по мере увеличения количества автомобилей в каждой категории в виде процентов.
# Дополнительное форматирование меток с помощью textprops. Обратите внимание, что это словарь.

plt.figure(figsize = (10, 8))
plt.pie(df_fuel_engine_type['Number of Cars'],
        labels = df_fuel_engine_type['Engine Fuel Type'].values,
        autopct = '%.2f%%',
        textprops = {'size' : 'x-large',
                     'fontweight' : 'bold',
                     'rotation' : 'horizontal',
                     'color' : 'w'})
plt.legend()
plt.title('Срез машин в зависимости от потребления топлива', fontsize = 18, fontweight = 'bold')
plt.show()

# %%
df_fuel_engine_types = pd.read_csv("https://raw.githubusercontent.com/trisha00001/EDA/main/stacked_area_chart_data.csv")
df_fuel_engine_types
# Out:
#     Year    Gas  Petrol  Diesel  Other
# 0   1982      0      94       0      0
# 1   1983      0     347       0      0
# 2   1984    300       0     334      0
# 3   1985   1030    1184     984      0
# 4   1986    511     681    1066    340
# 5   1987   1817    1840     400    940
# 6   1988   2999    1882    2060      1
# 7   1989   2626    1641    1304    330
# 8   1990   1290    3247       1      0
# 9   1991   1566    6776    1063    400
# 10  1992   2358    1925    2824    350
# 11  1993   1231    3375    2302      0
# 12  1994   2386    5691    2569     77
# 13  1995   2373    5115    4563    666
# 14  1996   4264    6792    6996   1235
# 15  1997   7031    7336    7877    370
# 16  1998   5578    7511    8634    310
# 17  1999   4069    6147   16742   1493
# 18  2000   6459   10754   23102    531
# 19  2001   3932    7590   22115   1029
# 20  2002   3375    7069   18144    479
# 21  2003   6032    8518   19605    281
# 22  2004   8332    7978   17400   1821
# ...

# %%
#  Создайте диаграмму с наложенными областями с помощью pyplots 'stackplot'. На оси x у нас есть временная линия - с 1982 по 2016 год.
# На оси y у нас есть три категории: "Дизельное топливо", "Бензин" и "Газ", расположенные друг над другом.
# Обратите внимание, что этот порядок выбран специально для того, чтобы категории были от самых больших к самым маленьким.
# Это помогает нам сравнить размер категорий, поскольку люди испытывают трудности с определением размера непрямоугольных фигур.

# Предоставьте список цветов, чтобы каждая категория могла иметь определенный цвет.
# Названия цветов должны отображаться в том же порядке, в каком отображаются категории наложенных областей.
colors = ["#011638", "#7e2987", "#ef2026"]
# список меток для легенды. Названия должны отображаться в том же порядке, в каком отображаются категории участков с наложенной областью.
labels = ["Дизель", "Бензин", "Газ"]
sns.set_style("white") # Используйте "белую" тему seaborn, чтобы ввести белый фон вместо серого по умолчанию.
plt.figure(figsize = (12, 6))
plt.stackplot(df_fuel_engine_types["Year"],
              df_fuel_engine_types["Diesel"],
              df_fuel_engine_types["Petrol"],
              df_fuel_engine_types["Gas"],
              colors = colors,
              edgecolor = 'none')# метод, показатель модуля библиотек matplotlib библиотека используется для получения кромки цвет фигуры прямоугольник.
plt.xticks(df_fuel_engine_types["Year"], rotation = 45) # Включите метки по оси x для каждого года и поверните метки на 45 градусов.
plt.legend(labels = labels, loc = "upper left") # Добавьте условное обозначение и укажите его местоположение на диаграмме.
plt.ylabel("Количество машин", fontsize = 13)
plt.title("Соотношение видов моторного топлива (1982 - 2016)", fontsize = 14, weight = "bold")
sns.despine() # Удалите верхнюю и правую границы диаграммы.
plt.show()

# %%
df_spx_ftse_00_10 = pd.read_csv("https://raw.githubusercontent.com/trisha00001/EDA/main/line_chart_data.csv")
df_spx_ftse_00_10
# Out:
#             Date   GSPC500   FTSE100
# 0       1/3/2000  0.003264  0.000000
# 1       1/4/2000 -0.009549  0.000000
# 2       1/5/2000 -0.038345 -0.038137
# 3       1/6/2000  0.001922 -0.019502
# 4       1/7/2000  0.000956 -0.013571
# ...          ...       ...       ...
# 2865  12/27/2010 -0.002282  0.002135
# 2866  12/28/2010  0.003539  0.000000
# 2867  12/29/2010 -0.000254  0.000000
# 2868  12/30/2010  0.000524 -0.002080
# 2869  12/31/2010 -0.002128 -0.004236
#
# [2870 rows x 3 columns]

# %%
# Преобразовать "Дату" в формат datetime. В противном случае это будет рассматриваться как простая строка
# поэтому операции или преобразования в столбце даты не приведут к желаемому результату.
# Это важнейший шаг в любом анализе временных рядов.
df_spx_ftse_00_10["new_date"] = pd.to_datetime(df_spx_ftse_00_10["Date"])

# %%
#линейный график для двух индексов: S&P 500 (синим цветом) и FTSE 100 (оранжевым). Временной период - с 2000 года до конца 2010 года
labels = ["S&P 500", "FTSE 100"] #список для легенды
plt.figure(figsize = (20, 8))
plt.plot(df_spx_ftse_00_10["new_date"], df_spx_ftse_00_10["GSPC500"])
plt.plot(df_spx_ftse_00_10["new_date"], df_spx_ftse_00_10["FTSE100"])
# заголовок, подписи легенда
plt.title("S&P и FTSE в период (2000 - 2010)", fontsize = 14, fontweight = "bold")
plt.ylabel("Значения")
plt.xlabel("Дата")
plt.legend(labels = labels, fontsize = "large")
plt.show()

# %%
df_real_estate = pd.read_csv("https://raw.githubusercontent.com/trisha00001/EDA/main/histogram_data.csv")
df_real_estate
# Out:
#        ID  Building Type  Year of sale  Month of sale Type of property  \
# 0    1030              1        2005.0           11.0        Apartment
# 1    1029              1        2005.0           10.0        Apartment
# 2    2002              2        2007.0            7.0        Apartment
# 3    2031              2        2007.0           12.0        Apartment
# 4    1049              1        2004.0           11.0        Apartment
# ..    ...            ...           ...            ...              ...
# 262  5044              5           NaN            NaN        Apartment
# 263  5047              5           NaN            NaN        Apartment
# 264  5048              5           NaN            NaN        Apartment
# 265  5050              5           NaN            NaN        Apartment
# 266  5051              5           NaN            NaN        Apartment
#
#      Property #  Area (ft.)  Price
# 0            30      743.09    246
# 1            29      756.21    246
# ...

# %%
sns.set_style("white") # переопределите стиль matplotlib по умолчанию, чтобы избежать серого фона и сетки
plt.figure(figsize = (8, 6)) #размер рисунка
plt.hist(df_real_estate["Price"], # переменная, на основе которой будет создана гистограмма
         bins = 8, # 8 бинов гистограммы
         color = "#108A99")
plt.title("Распределение цен на недвижимость", fontsize = 14, weight = "bold")
plt.xlabel("Цена (000's $)")
plt.ylabel("Количество")
sns.despine() #удаляет верхнюю и правую границы нашего графика
plt.show()

# %%
plt.hist
# Out:
# <function matplotlib.pyplot.hist(x: 'ArrayLike | Sequence[ArrayLike]', bins: 'int | Sequence[float] | str | None' = None, *, range: 'tuple[float, float] | None' = None, density: 'bool' = False, weights: 'ArrayLike | None' = None, cumulative: 'bool | float' = False, bottom: 'ArrayLike | float | None' = None, histtype: "Literal['bar', 'barstacked', 'step', 'stepfilled']" = 'bar', align: "Literal['left', 'mid', 'right']" = 'mid', orientation: "Literal['vertical', 'horizontal']" = 'vertical', rwidth: 'float | None' = None, log: 'bool' = False, color: 'ColorType | Sequence[ColorType] | None' = None, label: 'str | Sequence[str] | None' = None, stacked: 'bool' = False, data=None, **kwargs) -> 'tuple[np.ndarray | list[np.ndarray], np.ndarray, BarContainer | Polygon | list[BarContainer | Polygon]]'>

# %%
df_real_estate = pd.read_csv("https://raw.githubusercontent.com/trisha00001/EDA/main/scatter_data.csv")
df_real_estate
# Out:
#        ID  Building Type  Year of sale  Month of sale Type of property  \
# 0    1030              1        2005.0           11.0        Apartment
# 1    1029              1        2005.0           10.0        Apartment
# 2    2002              2        2007.0            7.0        Apartment
# 3    2031              2        2007.0           12.0        Apartment
# 4    1049              1        2004.0           11.0        Apartment
# ..    ...            ...           ...            ...              ...
# 262  5044              5           NaN            NaN        Apartment
# 263  5047              5           NaN            NaN        Apartment
# 264  5048              5           NaN            NaN        Apartment
# 265  5050              5           NaN            NaN        Apartment
# 266  5051              5           NaN            NaN        Apartment
#
#      Property #  Area (ft.)      Price    Status
# 0            30      743.09  246.17268     Sold
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

#define data
x = [3, 4, 4, 6, 8, 9]
y = [12, 14, 17, 16, 11, 13]

#define values, classes, and colors to map
values = [0, 0, 1, 2, 2, 2]
classes = ['A', 'B', 'C']
colors = ListedColormap(['red', 'blue', 'purple'])

#create scatterplot
scatter = plt.scatter(x, y, c=values, cmap=colors)

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

#define data
x = [3, 4, 4, 6, 8, 9]
y = [12, 14, 17, 16, 11, 13]

#define values, classes, and colors to map
values = [0, 0, 1, 2, 2, 2]
#add legend with values
plt.legend(*scatter.legend_elements(),loc = 'center left')

# %%
# точечная диаграмма с pyplot matplotlib. В зависимости от того, какие функции вы хотите включить,
# эта версия может не предоставлять столько возможностей высокого уровня, как seaborn. Однако технически он должен работать не хуже.\.
plt.figure(figsize = (12, 8)) # размер
scatter = plt.scatter(df_real_estate['Area (ft.)'],
            df_real_estate['Price'],
            alpha = 0.6, #уровень прозрачности точек на графике. Используется, чтобы избежать перерисовки
            c = df_real_estate['Building Type'], # дополнительный третий аргумент
            cmap = 'viridis') #цветовая карта
#добавлять и форматировать дополнительные элементы, такие как легенды, заголовки и метки осей.
plt.legend(*scatter.legend_elements(),
           loc = "upper left",
           title = "Тип недвижимости")
plt.title("Взаимосвязь между ценой и площадью",
          fontsize = 14,
          weight = "bold")
plt.xlabel("Площадь(кв. м.)", weight = "bold")
plt.ylabel("Цена (000's of $)")
plt.show()

# %%
# точечная диаграмма с pyplot matplotlib. В зависимости от того, какие функции вы хотите включить,
# эта версия может не предоставлять столько возможностей высокого уровня, как seaborn. Однако технически он должен работать не хуже.\.
plt.figure(figsize = (12, 8)) # размер
scatter = plt.scatter(df_real_estate['Area (ft.)'],
            df_real_estate['Price'],
            alpha = 0.6, #уровень прозрачности точек на графике. Используется, чтобы избежать перерисовки
            c = df_real_estate['Building Type'], # дополнительный третий аргумент
            cmap = 'viridis') #цветовая карта
#добавлять и форматировать дополнительные элементы, такие как легенды, заголовки и метки осей.
plt.legend(
           loc = "upper left",
           title = "Тип недвижимости")
plt.title("Взаимосвязь между ценой и площадью",
          fontsize = 14,
          weight = "bold")
plt.xlabel("Площадь(кв. м.)", weight = "bold")
plt.ylabel("Цена (000's of $)")
plt.show()
# Out:
# <ipython-input-22-24875903>:10: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(

# %%
# Seaborn проще в использовании
# он не поддерживает много опций как Mathplotlib
plt.figure(figsize = (12, 8))
sns.scatterplot(x = df_real_estate['Price'],
                y = df_real_estate['Area (ft.)'],
                hue = df_real_estate['Building Type'], #третий параметр типов
                palette = ['black', 'darkblue', 'purple', 'pink', 'white'], #цветовые параметры
                s = 100) # размер точек
plt.title("Взаимосвязь между ценой и площадью",
          fontsize = 14,
          weight = "bold")
plt.xlabel("Площадь  (кв. м.)", weight = "bold")
plt.ylabel("Цена (000 $)")
plt.show()

# %%
df_ad_expenditure = pd.read_csv("https://raw.githubusercontent.com/trisha00001/EDA/main/scatter_plot_ii.csv")
df_ad_expenditure
# Out:
#      Budget  Sales
# 0     337.1   22.1
# 1     128.9   10.4
# 2     132.4    9.3
# 3     251.3   18.5
# 4     250.0   12.9
# ..      ...    ...
# 195    55.7    7.6
# 196   107.2    9.7
# 197   192.7   12.8
# 198   391.8   25.5
# 199   249.4   13.4
#
# [200 rows x 2 columns]

# %%
# regplot принимает x и y в различных форматах. Для regplot данные должны быть строками в так называемой «длинной форме»
#plt.figure(figsize = (10, 8))
sns.set(rc = {'figure.figsize': (9,6)}) # фиксирует размер с помощью словаря
sns.regplot(x = "Budget",
            y = "Sales",
            data = df_ad_expenditure,
            scatter_kws = {'color': 'k'}, # цвет точек
            line_kws = {'color': 'red'}) # цвет линии регрессии
plt.xlabel("Расходы на рекламу в (000 $)")
plt.ylabel("Продажм (000 шт.)")
plt.title("Влияние расходов на рекламу на продажи", fontsize = 14, weight = "bold")
plt.show()

# %%
from matplotlib.ticker import PercentFormatter #преобразует значения в процентный формат

# %%
df_kdnuggets = pd.read_csv("https://raw.githubusercontent.com/trisha00001/EDA/main/bar_line_chart_data.csv") #read in the KDnuggets survey data file

# %%
df_kdnuggets #датафрейм, который мы будем использовать для создания комбинированного графика. Две диаграммы будут иметь общую ось X, которая соответствует году.
#На гистограмме количество участников будет указано на основной оси X (в левой части диаграммы).
# На линейной диаграмме пользователи Python будут указаны в процентах на вторичной оси Y (в правой части диаграммы).
# Out:
#    Year  Python Users  Participants
# 0  2012         0.149           798
# 1  2013         0.133          1880
# 2  2014         0.195          3285
# 3  2015         0.303          2800
# 4  2016         0.458          2895
# 5  2017         0.526          2900
# 6  2018         0.656          2300
# 7  2019         0.658          1800

# %%
# Создание комбинированной диаграммы. Здесь мы используем фигуру с осями.
# Первая ось или подграфик представляет собой гистограмму, вторая — линейную диаграмму.
fig, ax = plt.subplots(figsize = (10, 7))

#создание и стилизация гистограммы
ax.bar(df_kdnuggets["Year"],
       df_kdnuggets["Participants"],
       color = "k")
ax.set_ylabel("Количество пользователей",
              weight = "bold")
ax.tick_params(axis = "y",
               width = 2,
               labelsize = "large")
ax1 = ax.twinx()
#изменение вторичной оси Y для отображения процентов по шкале от 0% до 100%
ax1.set_ylim(0, 1)
ax1.yaxis.set_major_formatter(PercentFormatter(xmax = 1.0))
#создание и стилизация линейного графика
ax1.plot(df_kdnuggets["Year"],
         df_kdnuggets["Python Users"],
         color = "#b60000",
         marker = "D")
ax1.set_ylabel("Пользователи Python",
               color = "#b60000",
               weight = "bold")
ax1.tick_params(axis = "y",
                colors = "#b60000",
                width = 2,
                labelsize = "large")
ax.set_title("Опрос пользователей Python (2012 - 2019)", fontsize = "14", weight = "bold")
plt.show()
