# %% [markdown]
# **<center> ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕ ОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ</center>**
# **<center>ГОРОДА МОСКВЫ</center>**
# **<center>ДОПОЛНИТЕЛЬНОГО ПРОФЕССИОНАЛЬНОГО ОБРАЗОВАНИЯ</center>**
# **<center>ЦЕНТР ПРОФЕССИОНАЛЬНЫХ КВАЛИФИКАЦИЙ И СОДЕЙСТВИЯ ТРУДОУСТРОЙСТВУ</center>**
# **<center>«ПРОФЕССИОНАЛ»</center>**
# <br>
# <br>
# <br>
# <br>
#
# <br>
# <br>
# <br>
# <br>
#
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# <center> ИТОГОВАЯ АТТЕСТАЦИОННАЯ РАБОТА </center>
# <center> на тему </center>
# <center> «Анализ данных с использованием Python» </center>
# <center> (на примере анализа данных исследуемого продукта) </center>
# <center>слушателя Макеева Алексея Александровича<br>группы № 13 </center>
#  <center>по программе профессиональной переподготовки </center>
# <center> «Python для анализа данных» </center>
# <br>
# <br>
# <br>
# <br>
#
# <br>
# <br>
# <br>
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# <center> Москва, 2025

# %% [markdown]
# ### Цель исследования:

# %% [markdown]
# Цель данного проекта — выявить, какие признаки имеют наибольшее влияние на рейтинг вина, составляемого специализированным журналом Wine Enthusiast. Для анализа используется набор данных из Kaggle (профессиональное сообщество специалистов по обработке данных и машинному обучению). Датафрейм состоит из 13 признаков (2 числовых признака и 11 категориальных признаков).
#
# Анализ данных предполагает последовательное выполнение следующих этапов исследования:<br>
# <a href=#1>1.  Предобработка данных</a><br>
# <a href=#2>2.  Исследовательский анализ данных</a><br>
# <a href=#3>3.  Составление структуры развития рынка вина каждого региона</a><br>
# <a href=#4>4.  Проведение исследования статистических показателей зависимости цены вина от рейтинга в регионе</a><br>
# <a href=#5>5.  Проверка гипотез</a><br>
# <a href=#6>6.  Выводы</a><br>

# %% [markdown]
# ### Столбцы данных
# - Страна - страна происхождения вина.<br>
# - Описание — описание вкусового профиля вина.<br>
# - Обозначение - виноградник-поставщик винограда для изготовления вина.<br>
# - Рейтинг - оценка вина специализированным журналом Wine Enthusiast, выраженная в баллах по шкале от 1 до 100.<br>
# - Цена - цена одной бутылки вина.<br>
# - Провинция — регион (провинция, штат) производства вина.<br>
# - Регион 1 — зона виноделия в регионе (например, долина Напа в Калифорнии). <br>
# - Регион 2 — (необязательно) терруар виноделия - более конкретная область в винодельческом регионе (например, Резерфорд в долине Напа).<br>
# - Разновидность — сорт винограда, используемый в производстве вина (например, Пино Нуар).<br>
# - Винодельня — производитель вина.<br>

# %% [markdown]
# #  <a name="1">1.Предобработка данных</a>

# %% [markdown]
# Подготовка данных к анализу (очистка данных, трансформация данных, дополнение, оптимизация):
# * Заменить названия столбцов (привести к нижнему регистру).<br>
# * Преобразовать данные в нужные типы. Описать, в каких столбцах заменили тип данных и почему.<br>
# * Обработать пропуски при необходимости. <br>
# * Внести новый столбец "Континенты" в случае необходимости<br> country_to_continent = {<br>
# 'Italy':'Europe',<br>
# 'Portugal':'Europe',<br>
# 'US':'North America',<br>
# 'Spain':'Europe',<br>
# 'France':'Europe',<br>
# 'Germany':'Europe',<br>
# 'Argentina':'Latin America',<br>
# 'Chile':'Latin America',<br>
# 'Australia': 'Oceania',<br>
# 'Austria': 'Europe',<br>
# 'South Africa': 'Africa',<br>
# 'New Zealand': 'Oceania',<br>
# 'Israel': 'Asia', <br>
# 'Hungary':'Europe',<br>
# 'Greece':'Europe',<br>
# 'Romania':'Europe',<br>
# 'Mexico':'Latin America',<br>
# 'Canada':'North America',<br>
# 'Turkey': 'Asia',<br>
# 'Czech Republic': 'Europe',<br>
# 'Slovenia': 'Europe',<br>
# 'Luxembourg': 'Europe',<br>
# 'Croatia': 'Europe',<br>
# 'Georgia':'Europe',<br>
# 'Uruguay': 'Latin America',<br>
# 'England': 'Europe',<br>
# 'Lebanon': 'Asia',<br>
# 'Serbia': 'Europe',<br>
# 'Brazil': 'Latin America',<br>
# 'Moldova': 'Europe',<br>
# 'Morocco':'Africa',<br>
# 'Peru':'Latin America',<br>
# 'India':'Asia',<br>
# 'Bulgaria':'Europe',<br>
# 'Cyprus': 'Europe',<br>
# 'Armenia':'Asia',<br>
# 'Switzerland':'Europe',<br>
# 'Bosnia and Herzegovina':'Europe',<br>
# 'Ukraine':'Europe',<br>
# 'Slovakia':'Europe',<br>
# 'Macedonia':'Europe',<br>
# 'China':'Asia',<br>
# 'Egypt':'Africa'<br>
# }

# %% [markdown]
# Импорт необходимых библиотек

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.cm as cm

import scipy.stats as st
# импорт библиотеки warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# Загрузка данных

# %%
df = pd.read_csv('wine_reviews.csv')
df
# Out:
#       country                                        description  \
# 0          US  With a delicate, silky mouthfeel and bright ac...
# 1       Italy  D'Alceo is a drop dead gorgeous wine that ooze...
# 2      France  The great dominance of Cabernet Sauvignon in t...
# 3       Italy  The modest cherry, dark berry and black tea no...
# 4          US  Exceedingly light in color, scent and flavor, ...
# ...       ...                                                ...
# 19995  France  Firm wine, with tannins to match the chunky st...
# 19996      US  The vineyard is on the Napa side of Carneros. ...
# 19997   Italy  Lighea is a terrific wine and an excellent pai...
# 19998   Italy  Organically farmed Cannonau grapes deliver sma...
# 19999      US  Grown on the Sonoma side of the appellation, i...
#
#            designation  points  price           province  \
# 0                  NaN      86   23.0         California
# 1              D'Alceo      96  275.0            Tuscany
# 2                  NaN      91   40.0           Bordeaux
# 3                  NaN      81   15.0            Tuscany
# 4                  NaN      83   25.0             Oregon
# ...                ...     ...    ...                ...
# 19995          Mansois      88   12.0   Southwest France
# 19996  Estate Vineyard      89   50.0         California
# 19997           Lighea      87   20.0  Sicily & Sardinia
# 19998        Le Sabbie      87    NaN  Sicily & Sardinia
# 19999              NaN      92   35.0         California
#
#                    region_1         region_2                   variety  \
# 0             Central Coast    Central Coast                Pinot Noir
# 1                   Toscana              NaN                 Red Blend
# 2                Haut-Médoc              NaN  Bordeaux-style Red Blend
# 3          Chianti Classico              NaN                Sangiovese
# 4              Rogue Valley  Southern Oregon                Pinot Noir
# ...                     ...              ...                       ...
# 19995             Marcillac              NaN                   Mansois
# 19996              Carneros      Napa-Sonoma                Pinot Noir
# 19997               Sicilia              NaN                   Zibibbo
# 19998  Cannonau di Sardegna              NaN                  Cannonau
# 19999              Carneros      Napa-Sonoma                     Syrah
#
#                       winery
# 0            MacMurray Ranch
# 1      Castello dei Rampolla
# 2         Château Bernadotte
# 3                    Valiano
# 4                 Deer Creek
# ...                      ...
# 19995     Lionel Osmin & Cie
# 19996              Bouchaine
# 19997            Donnafugata
# 19998                 Meloni
# 19999             Saintsbury
#
# [20000 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   country      20000 non-null  object
#  1   description  20000 non-null  object
#  2   designation  13999 non-null  object
#  3   points       20000 non-null  int64
#  4   price        18198 non-null  float64
#  5   province     20000 non-null  object
#  6   region_1     16543 non-null  object
#  7   region_2     8058 non-null   object
#  8   variety      20000 non-null  object
#  9   winery       20000 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 1.5+ MB

# %% [markdown]
# Количество значений в столбцах различается. Это говорит о том, что в данных есть пустые значения. Признак points и price числовые. С помощью библиотеки Seaborn построим тепловую карту для визуализации данных.

# %%
colours = ['#993366', '#FFFF00']
sns.heatmap(df.isnull(), cmap=sns.color_palette(colours))
# Decorations
plt.title('Матрица пропущенных значений набора данных', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.figtext(0.5, -0.2, "Рисунок 1. - Матрица пропущенных значений набора данных")
plt.show()

# %%
MissingValue = df.isnull().sum().sort_values(ascending = False)
Percent = (df.isnull().sum()/df.isnull().count()*100).sort_values(ascending = False)
MissingData = pd.concat([MissingValue, Percent], axis=1, keys=['Пропущенные значения', 'Процент'])
MissingData
# Out:
#              Пропущенные значения  Процент
# region_2                    11942   59.710
# designation                  6001   30.005
# region_1                     3457   17.285
# price                        1802    9.010
# description                     0    0.000
# country                         0    0.000
# province                        0    0.000
# points                          0    0.000
# variety                         0    0.000
# winery                          0    0.000

# %%
df.dtypes
# Out:
# country         object
# description     object
# designation     object
# points           int64
# price          float64
# province        object
# region_1        object
# region_2        object
# variety         object
# winery          object
# dtype: object

# %%
df.variety.value_counts()
# Out:
# variety
# Pinot Noir                  1945
# Chardonnay                  1893
# Cabernet Sauvignon          1636
# Red Blend                   1329
# Bordeaux-style Red Blend     952
#                             ...
# Moscatel Roxo                  1
# Gewürztraminer-Riesling        1
# Schwartzriesling               1
# Kalecik Karasi                 1
# Mansois                        1
# Name: count, Length: 420, dtype: int64

# %%
df.nlargest(5,'points')
# Out:
#       country                                        description  \
# 323    France  A wine that has created its own universe. It h...
# 5955    Italy  A perfect wine from a classic vintage, the 200...
# 17967      US  Impossibly aromatic. Hard to imagine greater c...
# 5195   France  98-100 Barrel sample. The aromas are so rich a...
# 7306       US  The only one of the Cayuse Syrahs that is co-f...
#
#              designation  points   price    province                 region_1  \
# 323       Clos du Mesnil     100  1400.0   Champagne                Champagne
# 5955             Masseto     100   460.0     Tuscany                  Toscana
# 17967           Red Wine     100   245.0  California               Rutherford
# 5195       Barrel sample      99     NaN    Bordeaux                Sauternes
# 7306   Cailloux Vineyard      99    65.0      Oregon  Walla Walla Valley (OR)
#
#            region_2                     variety                 winery
# 323             NaN                  Chardonnay                   Krug
# 5955            NaN                      Merlot  Tenuta dell'Ornellaia
# 17967          Napa              Cabernet Blend                  Sloan
# 5195            NaN  Bordeaux-style White Blend        Château d'Yquem
# 7306   Oregon Other                       Syrah                 Cayuse

# %%
r = df[df.points == df.points.max()]

# %%
print(f"Наилучшие рейтинги получают вина областей:{r.province.tolist()}")
# Out:
# Наилучшие рейтинги получают вина областей:['Champagne', 'Tuscany', 'California']

# %%
color = {
    "Chardonnay": "white",
    "Pinot Noir": "red",
    "Cabernet Sauvignon": "red",
    "Red Blend": "red",
    "Bordeaux-style Red Blend": "red",
    "Sauvignon Blanc": "white",
    "Syrah": "red",
    "Riesling": "red",
    "Merlot": "red",
    "Zinfandel": "red",
    "Sangiovese": "red",
    "Malbec": "red",
    "White Blend": "white",
    "Rosé": "other",
    "Tempranillo": "red",
    "Nebbiolo": "red",
    "Portuguese Red": "red",
    "Sparkling Blend": "other",
    "Shiraz": "red",
    "Corvina, Rondinella, Molinara": "red",
    "Rhône-style Red Blend": "red",
    "Barbera": "red",
    "Pinot Gris": "white",
    "Viognier": "white",
    "Bordeaux-style White Blend": "white",
    "Champagne Blend": "other",
    "Port": "red",
    "Grüner Veltliner": "white",
    "Gewürztraminer": "white",
    "Portuguese White": "white",
    "Petite Sirah": "red",
    "Carmenère": "red"
}

# %%
df['color'] = df['variety'].map(color)
df
# Out:
#       country                                        description  \
# 0          US  With a delicate, silky mouthfeel and bright ac...
# 1       Italy  D'Alceo is a drop dead gorgeous wine that ooze...
# 2      France  The great dominance of Cabernet Sauvignon in t...
# 3       Italy  The modest cherry, dark berry and black tea no...
# 4          US  Exceedingly light in color, scent and flavor, ...
# ...       ...                                                ...
# 19995  France  Firm wine, with tannins to match the chunky st...
# 19996      US  The vineyard is on the Napa side of Carneros. ...
# 19997   Italy  Lighea is a terrific wine and an excellent pai...
# 19998   Italy  Organically farmed Cannonau grapes deliver sma...
# 19999      US  Grown on the Sonoma side of the appellation, i...
#
#            designation  points  price           province  \
# 0                  NaN      86   23.0         California
# 1              D'Alceo      96  275.0            Tuscany
# 2                  NaN      91   40.0           Bordeaux
# 3                  NaN      81   15.0            Tuscany
# 4                  NaN      83   25.0             Oregon
# ...                ...     ...    ...                ...
# 19995          Mansois      88   12.0   Southwest France
# 19996  Estate Vineyard      89   50.0         California
# 19997           Lighea      87   20.0  Sicily & Sardinia
# 19998        Le Sabbie      87    NaN  Sicily & Sardinia
# 19999              NaN      92   35.0         California
#
#                    region_1         region_2                   variety  \
# 0             Central Coast    Central Coast                Pinot Noir
# 1                   Toscana              NaN                 Red Blend
# 2                Haut-Médoc              NaN  Bordeaux-style Red Blend
# 3          Chianti Classico              NaN                Sangiovese
# 4              Rogue Valley  Southern Oregon                Pinot Noir
# ...                     ...              ...                       ...
# 19995             Marcillac              NaN                   Mansois
# 19996              Carneros      Napa-Sonoma                Pinot Noir
# 19997               Sicilia              NaN                   Zibibbo
# 19998  Cannonau di Sardegna              NaN                  Cannonau
# 19999              Carneros      Napa-Sonoma                     Syrah
#
#                       winery color
# 0            MacMurray Ranch   red
# 1      Castello dei Rampolla   red
# 2         Château Bernadotte   red
# 3                    Valiano   red
# 4                 Deer Creek   red
# ...                      ...   ...
# 19995     Lionel Osmin & Cie   NaN
# 19996              Bouchaine   red
# 19997            Donnafugata   NaN
# 19998                 Meloni   NaN
# 19999             Saintsbury   red
#
# [20000 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# country            0
# description        0
# designation     6001
# points             0
# price           1802
# province           0
# region_1        3457
# region_2       11942
# variety            0
# winery             0
# color           3501
# dtype: int64

# %%
df.dropna(inplace = True, subset = 'color')

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'points'}>,
#         <Axes: title={'center': 'price'}>]], dtype=object)

# %%
plt.figure(figsize = (14,6))
plt.hist(df.points.to_list(),color='purple')
plt.title('Распределение вин по рейтингу')
plt.xlabel('Рейтинг')
plt.ylabel('Доля')
plt.grid()
plt.figtext(0.4, -0.01, "Рисунок 1. - Распределение вин по рейтингу", fontsize =20)
# Out:
# Text(0.4, -0.01, 'Рисунок 1. - Распределение вин по рейтингу')

# %%
sns.distplot(df['points'])
# Out:
# /tmp/ipython-input-16-2930857788.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['points'])
# <Axes: xlabel='points', ylabel='Density'>

# %%
a=pd.crosstab(df['country'],df['color'],normalize='index').round(2)
a
# Out:
# color         other   red  white
# country
# Argentina      0.02  0.84   0.14
# Australia      0.03  0.71   0.27
# Austria        0.02  0.35   0.63
# Brazil         1.00  0.00   0.00
# Bulgaria       0.00  0.67   0.33
# Canada         0.00  0.86   0.14
# Chile          0.02  0.70   0.28
# China          0.00  0.00   1.00
# Croatia        0.14  0.29   0.57
# Cyprus         0.00  0.83   0.17
# France         0.16  0.53   0.31
# Georgia        0.00  0.00   1.00
# Germany        0.00  0.98   0.02
# Greece         0.04  0.55   0.41
# Hungary        0.17  0.58   0.25
# Israel         0.03  0.68   0.29
# Italy          0.05  0.83   0.12
# Lebanon        0.00  0.33   0.67
# Luxembourg     0.00  1.00   0.00
# Mexico         0.11  0.67   0.22
# Moldova        0.08  0.50   0.42
# New Zealand    0.00  0.46   0.54
# Portugal       0.05  0.73   0.22
# Romania        0.00  0.87   0.13
# Slovenia       0.00  0.56   0.44
# South Africa   0.02  0.57   0.41
# Spain          0.18  0.70   0.12
# Switzerland    0.00  1.00   0.00
# Turkey         0.00  1.00   0.00
# US             0.02  0.73   0.24
# US-France      0.00  0.00   1.00
# Ukraine        1.00  0.00   0.00
# Uruguay        0.00  0.83   0.17

# %%
max_white_wine = a[a['white']==a['white'].max()]
max_white_wine
# Out:
# color      other  red  white
# country
# China        0.0  0.0    1.0
# Georgia      0.0  0.0    1.0
# US-France    0.0  0.0    1.0

# %%
a.sort_values(by = 'white' , ascending = False)[:5]
# Out:
# color      other   red  white
# country
# China       0.00  0.00   1.00
# US-France   0.00  0.00   1.00
# Georgia     0.00  0.00   1.00
# Lebanon     0.00  0.33   0.67
# Austria     0.02  0.35   0.63

# %%
max_red_wine = a[a['red']==a['red'].max()]
max_red_wine
# Out:
# color        other  red  white
# country
# Luxembourg     0.0  1.0    0.0
# Switzerland    0.0  1.0    0.0
# Turkey         0.0  1.0    0.0

# %%
a=df.groupby(['country','color'])['color'].count().unstack()
a
# Out:
# color         other     red   white
# country
# Argentina      12.0   528.0    87.0
# Australia      14.0   359.0   135.0
# Austria         6.0   105.0   189.0
# Brazil          2.0     NaN     NaN
# Bulgaria        NaN     6.0     3.0
# Canada          NaN    18.0     3.0
# Chile          13.0   506.0   201.0
# China           NaN     NaN     2.0
# Croatia         1.0     2.0     4.0
# Cyprus          NaN     5.0     1.0
# France        387.0  1267.0   749.0
# Georgia         NaN     NaN     2.0
# Germany         1.0   323.0     7.0
# Greece          2.0    28.0    21.0
# Hungary         2.0     7.0     3.0
# Israel          2.0    54.0    23.0
# Italy          97.0  1620.0   225.0
# Lebanon         NaN     1.0     2.0
# Luxembourg      NaN     1.0     NaN
# Mexico          1.0     6.0     2.0
# Moldova         1.0     6.0     5.0
# New Zealand     1.0   201.0   236.0
# Portugal       30.0   464.0   140.0
# Romania         NaN    13.0     2.0
# Slovenia        NaN     5.0     4.0
# South Africa    5.0   141.0   100.0
# Spain         110.0   426.0    70.0
# Switzerland     NaN     1.0     NaN
# Turkey          NaN     6.0     NaN
# US            186.0  5484.0  1819.0
# US-France       NaN     NaN     1.0
# Ukraine         1.0     NaN     NaN
# Uruguay         NaN     5.0     1.0

# %%
white_wines = df[df['wine_color'] == 'white']# Фильтруем только белые вина
country_with_max_white = white_wines.loc[white_wines['wine_share'].idxmax()]['province']# страна с максимальной долей белого вина
red_wines = df[df['wine_color'] == 'red']# Фильтруем только красные вина
country_with_max_red = red_wines.loc[red_wines['wine_share'].idxmax()]['province']# страна с максимальной долей красного вина
result = f'В стране {country_with_max_white} наибольшая доля белого вина, а в стране {country_with_max_red} — красного.'
print(result)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'wine_color'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-96-545645465.py in <cell line: 0>()
# ----> 1 white_wines = df[df['wine_color'] == 'white']# Фильтруем только белые вина
#       2 country_with_max_white = white_wines.loc[white_wines['wine_share'].idxmax()]['province']# страна с максимальной долей белого вина
#       3 red_wines = df[df['wine_color'] == 'red']# Фильтруем только красные вина
#       4 country_with_max_red = red_wines.loc[red_wines['wine_share'].idxmax()]['province']# страна с максимальной долей красного вина
#       5 result = f'В стране {country_with_max_white} наибольшая доля белого вина, а в стране {country_with_max_red} — красного.'
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'wine_color'

# %% [markdown]
# #  <a name="2"> 2. Исследовательский анализ данных</a>
# * Найти среднюю цену вина по региону.
# * Выбрать сорта с наибольшими ценами.
# * Найти среднюю цену вина для региона.
# * Определить, популярные сорта вина в бюджетном сегменте.
# * Определить, какие сорта вина лидируют по рейтингам.
# * Построить график «ящик с усами» по рейтингам в разбивке по странам, по сортам вина.
# * Выявить закономерность влияния на цену  цвета и рейтинга вина.
# * Построить диаграмму рассеяния и посчитать корреляцию.

# %%
df.describe()
# Out:
#              points         price
# count  16499.000000  15041.000000
# mean      87.994303     34.487202
# std        3.298385     41.674428
# min       80.000000      5.000000
# 25%       86.000000     16.000000
# 50%       88.000000     25.000000
# 75%       90.000000     40.000000
# max      100.000000   2300.000000

# %%
df.describe(include=['O'])
# Out:
#        country                                        description designation  \
# count    16499                                              16499       11637
# unique      33                                              15566        7386
# top         US  As sweet as a brown-sugared power bar, with ch...     Reserve
# freq      7489                                                  3         319
#
#           province     region_1       region_2     variety           winery  \
# count        16499        13581           7344       16499            16499
# unique         265          723             18          32             6396
# top     California  Napa Valley  Central Coast  Pinot Noir  Williams Selyem
# freq          5407          736           1553        1945               55
#
#         color
# count   16499
# unique      3
# top       red
# freq    11588

# %%
df["country"].describe()
# Out:
# count     16499
# unique       33
# top          US
# freq       7489
# Name: country, dtype: object

# %%
df_country = df['country'].value_counts().to_frame()
df_country.reset_index(inplace=True)
df_country.columns = ['country','counts']
fig, ax = plt.subplots(figsize=(15,10));
sns.barplot(data = df_country, x='country',y='counts',ax=ax).set_title('Количество образцов по каждой стране');
plt.figtext(0.4, -0.1, "Рисунок 2. - Распределение по странам ")
plt.xticks(rotation='vertical');

# %%
countries_list = pd.DataFrame(df.country.value_counts(dropna = True)).iloc[0:10]
countries_list['Index'] = list(range(0,10))
countries_list['Country_Name'] = countries_list.index.values
countries_list.set_index('Index',inplace = True)
countries_list.columns = ['Number Of Wines Produced','Country']

countries_list
# Out:
#        Number Of Wines Produced      Country
# Index
# 0                          7489           US
# 1                          2403       France
# 2                          1942        Italy
# 3                           720        Chile
# 4                           634     Portugal
# 5                           627    Argentina
# 6                           606        Spain
# 7                           508    Australia
# 8                           438  New Zealand
# 9                           331      Germany

# %%
# Comparing rating per continent

#creating dictionary for country and its continent
country_to_continent = {
    'Italy':'Europe',
    'Portugal':'Europe',
    'US':'North America',
    'Spain':'Europe',
    'France':'Europe',
    'Germany':'Europe',
    'Argentina':'Latin America',
    'Chile':'Latin America',
    'Australia': 'Oceania',
    'Austria': 'Europe',
    'South Africa': 'Africa',
    'New Zealand': 'Oceania',
    'Israel': 'Asia',
    'Hungary':'Europe',
    'Greece':'Europe',
    'Romania':'Europe',
    'Mexico':'Latin America',
    'Canada':'North America',
    'Turkey': 'Asia',
    'Czech Republic': 'Europe',
    'Slovenia': 'Europe',
    'Luxembourg': 'Europe',
    'Croatia': 'Europe',
    'Georgia':'Europe',
    'Uruguay': 'Latin America',
    'England': 'Europe',
    'Lebanon': 'Asia',
    'Serbia': 'Europe',
    'Brazil': 'Latin America',
    'Moldova': 'Europe',
    'Morocco':'Africa',
    'Peru':'Latin America',
    'India':'Asia',
    'Bulgaria':'Europe',
    'Cyprus': 'Europe',
    'Armenia':'Asia',
    'Switzerland':'Europe',
    'Bosnia and Herzegovina':'Europe',
    'Ukraine':'Europe',
    'Slovakia':'Europe',
    'Macedonia':'Europe',
    'China':'Asia',
    'Egypt':'Africa'
    }
# wine_df['country'].unique()
# type(country)

#adding column to put column from the country
df['continent'] =df['country'].map(country_to_continent)
df
# Out:
#             country                                        description  \
# 0                US  With a delicate, silky mouthfeel and bright ac...
# 1             Italy  D'Alceo is a drop dead gorgeous wine that ooze...
# 2            France  The great dominance of Cabernet Sauvignon in t...
# 3             Italy  The modest cherry, dark berry and black tea no...
# 4                US  Exceedingly light in color, scent and flavor, ...
# ...             ...                                                ...
# 19991  South Africa  Muscular spice, deep red berry and blackberry ...
# 19993        France  A beautifully elegant wine, wearing its fresh ...
# 19994            US  A little too strong in feline spray character,...
# 19996            US  The vineyard is on the Napa side of Carneros. ...
# 19999            US  Grown on the Sonoma side of the appellation, i...
#
#                  designation  points  price      province          region_1  \
# 0                        NaN      86   23.0    California     Central Coast
# 1                    D'Alceo      96  275.0       Tuscany           Toscana
# 2                        NaN      91   40.0      Bordeaux        Haut-Médoc
# 3                        NaN      81   15.0       Tuscany  Chianti Classico
# 4                        NaN      83   25.0        Oregon      Rogue Valley
# ...                      ...     ...    ...           ...               ...
# 19991                 Estate      90   27.0  Stellenbosch               NaN
# 19993  Montmains Premier Cru      94   32.0      Burgundy           Chablis
# 19994          Grand Reserve      84   20.0    California  Mendocino County
# 19996        Estate Vineyard      89   50.0    California          Carneros
# 19999                    NaN      92   35.0    California          Carneros
#
#                       region_2                   variety  \
# 0                Central Coast                Pinot Noir
# 1                          NaN                 Red Blend
# 2                          NaN  Bordeaux-style Red Blend
# 3                          NaN                Sangiovese
# 4              Southern Oregon                Pinot Noir
# ...                        ...                       ...
# 19991                      NaN                    Shiraz
# 19993                      NaN                Chardonnay
# 19994  Mendocino/Lake Counties           Sauvignon Blanc
# 19996              Napa-Sonoma                Pinot Noir
# 19999              Napa-Sonoma                     Syrah
#
#                       winery  color      continent
# 0            MacMurray Ranch    red  North America
# 1      Castello dei Rampolla    red         Europe
# 2         Château Bernadotte    red         Europe
# 3                    Valiano    red         Europe
# 4                 Deer Creek    red  North America
# ...                      ...    ...            ...
# 19991          Rust en Vrede    red         Africa
# 19993          William Fèvre  white         Europe
# 19994        Kendall-Jackson  white  North America
# 19996              Bouchaine    red  North America
# 19999             Saintsbury    red  North America
#
# [16499 rows x 12 columns]

# %%
df_country = df['continent'].value_counts().to_frame()
df_country.reset_index(inplace=True)
df_country.columns = ['continent','counts']
fig, ax = plt.subplots(figsize=(15,10));
sns.barplot(data = df_country, x='continent',y='counts',ax=ax).set_title('Количество образцов по каждому континенту');
plt.figtext(0.4, -0.1, "Рисунок 3. - Распределение по континентам ")
plt.xticks(rotation='vertical');

# %%
df.designation.value_counts()
df.designation.value_counts()[:10]
# Out:
# designation
# Reserve           319
# Reserva           201
# Estate            197
# Barrel sample     175
# Barrel Sample      76
# Riserva            65
# Estate Grown       53
# Brut               50
# Estate Bottled     48
# Old Vine           39
# Name: count, dtype: int64

# %%
df["points"].describe()
# Out:
# count    16499.000000
# mean        87.994303
# std          3.298385
# min         80.000000
# 25%         86.000000
# 50%         88.000000
# 75%         90.000000
# max        100.000000
# Name: points, dtype: float64

# %%
sns.histplot(df.points, kde=False)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.xlabel("Рейтинг")
plt.ylabel("Количество вина")
plt.title("Количество вина для каждого рейтинга")
df.groupby(['points']).count()['description'].plot(ax=ax, kind='bar')
plt.figtext(0.4, 0, "Рисунок 4. - Гистограмма частоты признака Points ")
plt.show()

# %%
df['points'].value_counts().sort_index().plot.area()
plt.figtext(0.5, -0.2, "Рисунок 5. - Полиглн частот признака Points" )
# Out:
# Text(0.5, -0.2, 'Рисунок 5. - Полиглн частот признака Points')

# %%
avg_rating = df["points"].mean()
avg_rating
# Out:
# np.float64(87.9943026850112)

# %%
def GoodRating(row):
    if row['points'] >= 88:
        val = 1
    else:
        val = 0
    return(val)
df['Good'] = df.apply(GoodRating, axis=1)
df.head()
# Out:
#   country                                        description designation  \
# 0      US  With a delicate, silky mouthfeel and bright ac...         NaN
# 1   Italy  D'Alceo is a drop dead gorgeous wine that ooze...     D'Alceo
# 2  France  The great dominance of Cabernet Sauvignon in t...         NaN
# 3   Italy  The modest cherry, dark berry and black tea no...         NaN
# 4      US  Exceedingly light in color, scent and flavor, ...         NaN
#
#    points  price    province          region_1         region_2  \
# 0      86   23.0  California     Central Coast    Central Coast
# 1      96  275.0     Tuscany           Toscana              NaN
# 2      91   40.0    Bordeaux        Haut-Médoc              NaN
# 3      81   15.0     Tuscany  Chianti Classico              NaN
# 4      83   25.0      Oregon      Rogue Valley  Southern Oregon
#
#                     variety                 winery color      continent  Good
# 0                Pinot Noir        MacMurray Ranch   red  North America     0
# 1                 Red Blend  Castello dei Rampolla   red         Europe     1
# 2  Bordeaux-style Red Blend     Château Bernadotte   red         Europe     1
# 3                Sangiovese                Valiano   red         Europe     0
# 4                Pinot Noir             Deer Creek   red  North America     0

# %%
fig = plt.figure(figsize=(18,12))
top_reviewed_wines = df.variety.value_counts().head(10)
points_top_reviewed_wines = df[df.variety.isin(top_reviewed_wines.index)]


sns.boxplot(x = points_top_reviewed_wines.variety,y = points_top_reviewed_wines.points)
plt.xlabel('Сорт винограда', fontsize=20)
plt.ylabel('Рейтинг', fontsize=20)
plt.title('Распределения рейтинга вина по топ 10 сортов винограда',fontsize=20)
plt.figtext(0.5, 0, "Рисунок 6. - Зависимость рейтинга от топ 10 популярных сортов винограда" )
# Out:
# Text(0.5, 0, 'Рисунок 6. - Зависимость рейтинга от топ 10 популярных сортов винограда')

# %%
res = pd.DataFrame(df[df['variety'] == 'Pinot Noir'].groupby('points').count()).iloc[:,0]
variety_points_dist = res
res = pd.DataFrame(df[df['variety'] == 'Chardonnay'].groupby('points').count()).iloc[:,0]
variety_points_dist = pd.concat([variety_points_dist,res],axis = 1)
res = pd.DataFrame(df[df['variety'] == 'Cabernet Sauvignon'].groupby('points').count()).iloc[:,0]
variety_points_dist = pd.concat([variety_points_dist,res],axis = 1)
res = pd.DataFrame(df[df['variety'] == 'Red Blend'].groupby('points').count()).iloc[:,0]
variety_points_dist = pd.concat([variety_points_dist,res],axis = 1)
res = pd.DataFrame(df[df['variety'] == 'Bordeaux-style Red Blend'].groupby('points').count()).iloc[:,0]
variety_points_dist = pd.concat([variety_points_dist,res],axis = 1)
variety_points_dist.columns = ['Pinot Noir','Chardonnay','Cabernet Sauvignon','Red Blend','Bordeaux-style Red Blend']
variety_points_dist
# Out:
#         Pinot Noir  Chardonnay  Cabernet Sauvignon  Red Blend  \
# points
# 80             7.0         9.0                 8.0        8.0
# 81            11.0        21.0                21.0       14.0
# 82            34.0        73.0                63.0       28.0
# 83            61.0        96.0                87.0       37.0
# 84            94.0       163.0               119.0       94.0
# 85           127.0       150.0               145.0       86.0
# 86           180.0       201.0               135.0      125.0
# 87           233.0       282.0               189.0      178.0
# 88           200.0       188.0               146.0      189.0
# 89           165.0       111.0               119.0      140.0
# 90           206.0       192.0               167.0      136.0
# 91           153.0       121.0               112.0      119.0
# 92           183.0       110.0               135.0       66.0
# 93           128.0        80.0                80.0       59.0
# 94            94.0        49.0                61.0       30.0
# 95            44.0        27.0                33.0       10.0
# 96            16.0        14.0                 8.0        3.0
# 97             6.0         4.0                 6.0        6.0
# 98             3.0         1.0                 2.0        1.0
# 100            NaN         1.0                 NaN        NaN
# 99             NaN         NaN                 NaN        NaN
#
#         Bordeaux-style Red Blend
# points
# 80                           1.0
# 81                           4.0
# 82                           6.0
# 83                          17.0
# 84                          43.0
# 85                          53.0
# 86                          63.0
# 87                          99.0
# 88                          95.0
# 89                          82.0
# 90                         126.0
# 91                         110.0
# 92                          93.0
# 93                          65.0
# 94                          35.0
# 95                          32.0
# 96                          13.0
# 97                          11.0
# 98                           2.0
# 100                          NaN
# 99                           2.0

# %%
wines = df.pivot_table(values='points',index=['variety'],columns=['country'],aggfunc='mean')
wines.head()
# Out:
# country                     Argentina  Australia  Austria  Brazil  Bulgaria  \
# variety
# Barbera                           NaN        NaN      NaN     NaN       NaN
# Bordeaux-style Red Blend     89.31250  88.722222     92.0     NaN       NaN
# Bordeaux-style White Blend   83.00000        NaN      NaN     NaN       NaN
# Cabernet Sauvignon           85.12037  88.142857      NaN     NaN      83.0
# Carmenère                         NaN        NaN      NaN     NaN       NaN
#
# country                     Canada      Chile  China  Croatia  Cyprus  ...  \
# variety                                                                ...
# Barbera                        NaN        NaN    NaN      NaN     NaN  ...
# Bordeaux-style Red Blend       NaN  89.714286    NaN      NaN     NaN  ...
# Bordeaux-style White Blend     NaN        NaN    NaN      NaN     NaN  ...
# Cabernet Sauvignon             NaN  86.441176    NaN      NaN     NaN  ...
# Carmenère                      NaN  86.011236    NaN      NaN     NaN  ...
#
# country                     Romania  Slovenia  South Africa  Spain  \
# variety
# Barbera                         NaN       NaN           NaN    NaN
# Bordeaux-style Red Blend        NaN      89.0     88.800000   85.5
# Bordeaux-style White Blend      NaN       NaN           NaN    NaN
# Cabernet Sauvignon             84.0       NaN     87.888889   85.0
# Carmenère                       NaN       NaN           NaN    NaN
#
# country                     Switzerland  Turkey         US  US-France  \
# variety
# Barbera                             NaN     NaN  86.297297        NaN
# Bordeaux-style Red Blend            NaN    87.0  89.060000        NaN
# Bordeaux-style White Blend          NaN     NaN  88.000000        NaN
# Cabernet Sauvignon                  NaN     NaN  88.582408        NaN
# Carmenère                           NaN     NaN  88.400000        NaN
#
# country                     Ukraine  Uruguay
# variety
# Barbera                         NaN      NaN
# Bordeaux-style Red Blend        NaN      NaN
# Bordeaux-style White Blend      NaN      NaN
# Cabernet Sauvignon              NaN     87.0
# Carmenère                       NaN      NaN
#
# [5 rows x 33 columns]

# %%
sns.heatmap(wines)
plt.figtext(0.5, -0.3, "Рисунок 7. - Зависимость сорта винограда от страны" )
# Out:
# Text(0.5, -0.3, 'Рисунок 7. - Зависимость сорта винограда от страны')

# %%
wines = df.pivot_table(values='points',index=['variety'],columns=['designation'],aggfunc='mean')
wines.head()
# Out:
# designation                 'A Naca Rosso  'l Clumbé  0 Degree Dry  0 Degrees  \
# variety
# Barbera                               NaN       87.0           NaN        NaN
# Bordeaux-style Red Blend              NaN        NaN           NaN        NaN
# Bordeaux-style White Blend            NaN        NaN           NaN        NaN
# Cabernet Sauvignon                    NaN        NaN           NaN        NaN
# Carmenère                             NaN        NaN           NaN        NaN
#
# designation                 1 Lage  1 er Cru Charmes  1-liter  10 Anos White  \
# variety
# Barbera                        NaN               NaN      NaN            NaN
# Bordeaux-style Red Blend       NaN               NaN      NaN            NaN
# Bordeaux-style White Blend     NaN               NaN      NaN            NaN
# Cabernet Sauvignon             NaN               NaN      NaN            NaN
# Carmenère                      NaN               NaN      NaN            NaN
#
# designation                 10 Vine Age Series  10 Year Old Tawny  ...  \
# variety                                                            ...
# Barbera                                    NaN                NaN  ...
# Bordeaux-style Red Blend                   NaN                NaN  ...
# Bordeaux-style White Blend                 NaN                NaN  ...
# Cabernet Sauvignon                         NaN                NaN  ...
# Carmenère                                  NaN                NaN  ...
#
# designation                 Étoile Brut  Ürziger Goldwingert Auslese  \
# variety
# Barbera                             NaN                          NaN
# Bordeaux-style Red Blend            NaN                          NaN
# Bordeaux-style White Blend          NaN                          NaN
# Cabernet Sauvignon                  NaN                          NaN
# Carmenère                           NaN                          NaN
#
# designation                 Ürziger Goldwingert Spätlese  Ürziger Würzgarten  \
# variety
# Barbera                                              NaN                 NaN
# Bordeaux-style Red Blend                             NaN                 NaN
# Bordeaux-style White Blend                           NaN                 NaN
# Cabernet Sauvignon                                   NaN                 NaN
# Carmenère                                            NaN                 NaN
#
# designation                 Ürziger Würzgarten Auslese  \
# variety
# Barbera                                            NaN
# Bordeaux-style Red Blend                           NaN
# Bordeaux-style White Blend                         NaN
# Cabernet Sauvignon                                 NaN
# Carmenère                                          NaN
#
# designation                 Ürziger Würzgarten Auslese *  \
# variety
# Barbera                                              NaN
# Bordeaux-style Red Blend                             NaN
# Bordeaux-style White Blend                           NaN
# Cabernet Sauvignon                                   NaN
# Carmenère                                            NaN
#
# designation                 Ürziger Würzgarten Auslese Goldkap  \
# variety
# Barbera                                                    NaN
# Bordeaux-style Red Blend                                   NaN
# Bordeaux-style White Blend                                 NaN
# Cabernet Sauvignon                                         NaN
# Carmenère                                                  NaN
#
# designation                 Ürziger Würzgarten Beerenauslese  \
# variety
# Barbera                                                  NaN
# Bordeaux-style Red Blend                                 NaN
# Bordeaux-style White Blend                               NaN
# Cabernet Sauvignon                                       NaN
# Carmenère                                                NaN
#
# designation                 Ürziger Würzgarten Kabinett  \
# variety
# Barbera                                             NaN
# Bordeaux-style Red Blend                            NaN
# Bordeaux-style White Blend                          NaN
# Cabernet Sauvignon                                  NaN
# Carmenère                                           NaN
#
# designation                 Ürziger Würzgarten Spätlese
# variety
# Barbera                                             NaN
# Bordeaux-style Red Blend                            NaN
# Bordeaux-style White Blend                          NaN
# Cabernet Sauvignon                                  NaN
# Carmenère                                           NaN
#
# [5 rows x 7386 columns]

# %%
sns.heatmap(wines)
plt.figtext(0.5, -0.8 , "Рисунок 8. - Зависимость сорта винограда от винодени" )
# Out:
# Text(0.5, -0.8, 'Рисунок 8. - Зависимость сорта винограда от винодени')

# %%
#количество просмотров количество отзывов в разбивке по странам винодельни, использующие максимальное количество сортов винограда
country= df.groupby('country').agg({'points': ['mean','median', 'var','std','sem']})

country['Counts'] =df['country'].value_counts()

# took out countries with less than 1000 reviews
country_1000 = country[country['Counts']>1000]
country_1000
# Out:
#             points                                       Counts
#               mean median        var       std       sem
# country
# France   89.091552   89.0  10.340491  3.215663  0.065598   2403
# Italy    88.746138   88.0   8.136963  2.852536  0.064730   1942
# US       87.881960   88.0  11.883768  3.447284  0.039835   7489

# %%
#sorted the data with rating
country_plot = pd.DataFrame(country_1000).reset_index()
#country_plot['points']['mean']
country_plot = country_plot.sort_values(('points','mean'), ascending=False)
country_plot
plt.xticks(rotation = 45)
plt.xlabel("Country")
plt.ylabel("Average of Rating")
plt.title("Country vs Rating")
plt.ylim(86,91)
# plt.legend(loc = "lower right")
plt.grid(alpha = 0.5)
# plt.errorbar(country_plot['country'], country_plot[('points','mean')], yerr=country_plot[('points','sem')])#,  c=country_plot['Counts'],cmap=cm.cool)
plt.scatter(country_plot['country'],country_plot[('points','mean')], c=country_plot['Counts'], cmap= cm.rainbow)
plt.colorbar(cmap=cm.rainbow, orientation='vertical', label = "Color by # of Reviews")
plt.show()

# %%
#Adding number of reviews by state column
america = df[df["country"].isin(["US"])]
state= america.groupby('province').agg({'points': ['mean','median', 'var','std','sem']})

state['Counts'] =america['province'].value_counts()
# took out states with less than 500 reviews
state_500 = state[state['Counts']>500]
# putting it back to dataframe to plot
state_plot = pd.DataFrame(state_500).reset_index()
state_plot = state_plot.sort_values(('points','mean'), ascending=False)
state_plot

# Plot graph
plt.scatter(state_plot['province'],state_plot[('points','mean')], c=state_plot['Counts'], cmap=cm.rainbow)
plt.xticks(rotation = 45)
plt.xlabel("State")
plt.ylabel("Average of Rating")
plt.title("State vs Rating")
plt.ylim(85,90)
plt.grid(alpha = 0.5)
plt.colorbar(cmap=cm.rainbow, orientation='vertical', label = "Color by # of Reviews")
plt.show()

# %%
mean_points = df['points'].groupby(df['country']).mean()
mean_points
# Out:
# country
# Argentina       86.296651
# Australia       88.029528
# Austria         89.320000
# Brazil          83.000000
# Bulgaria        84.111111
# Canada          87.476190
# Chile           86.261111
# China           82.000000
# Croatia         85.142857
# Cyprus          87.333333
# France          89.091552
# Georgia         84.000000
# Germany         89.000000
# Greece          85.764706
# Hungary         84.000000
# Israel          87.253165
# Italy           88.746138
# Lebanon         83.333333
# Luxembourg      86.000000
# Mexico          84.222222
# Moldova         84.500000
# New Zealand     87.616438
# Portugal        88.175079
# Romania         84.000000
# Slovenia        88.444444
# South Africa    87.105691
# Spain           86.458746
# Switzerland     86.000000
# Turkey          88.166667
# US              87.881960
# US-France       88.000000
# Ukraine         86.000000
# Uruguay         84.500000
# Name: points, dtype: float64

# %%
fig = plt.figure(figsize=(20,15))
top_country_wines = df.country.value_counts().head(10)
points_top_country_wines = df[df.country.isin(top_country_wines.index)]

sns.boxplot(x = points_top_country_wines.country, y = points_top_country_wines.points)
plt.xlabel('Country', fontsize=20)
plt.ylabel('Points', fontsize=20)
plt.title('Distribution of points in top 10 listed countries',fontsize=20)
plt.figtext(0.5, 0 , "Рисунок 10. -Топ  10" )
# Out:
# Text(0.5, 0, 'Рисунок 10. -Топ  10')

# %%
df['price'].describe()
# Out:
# count    15041.000000
# mean        34.487202
# std         41.674428
# min          5.000000
# 25%         16.000000
# 50%         25.000000
# 75%         40.000000
# max       2300.000000
# Name: price, dtype: float64

# %%
df['price'].value_counts().sort_index().plot.line()
plt.figtext(0.5, 0, "Рисунок 12. - График распределения цены" )
# Out:
# Text(0.5, 0, 'Рисунок 12. - График распределения цены')

# %%
avg_cost = df["price"].mean()
avg_cost
# Out:
# np.float64(34.48720164882654)

# %%
max_price =df [ 'price' ]. max ()

# %%
print ( "Самое дорогое вино ${:.2f}" . format ( max_price ) )
# Out:
# Самое дорогое вино $2300.00

# %%
df [df [ 'price' ]  == 2300 ]
# Out:
#       country                                        description designation  \
# 13188  France  A big, powerful wine that sums up the richness...         NaN
#
#        points   price  province  region_1 region_2                   variety  \
# 13188      99  2300.0  Bordeaux  Pauillac      NaN  Bordeaux-style Red Blend
#
#                winery color continent  Good
# 13188  Château Latour   red    Europe     1

# %%
min_price = df['price'].min()
print("Самое дешевое вино ${:.2f} USD".format(min_price))
# Out:
# Самое дешевое вино $5.00 USD

# %%
df[df['price'] == 5.0]
# Out:
#          country                                        description  \
# 27     Australia  Simultaneously pruny and herbal, this medium-w...
# 3583       Spain  How many $5 wines are this good? Not many. The...
# 4321   Australia  Possibly a little sweet, this is a soft, easyg...
# 6381    Portugal  Bright, crisp raspberry flavors on a bone-dry ...
# 14547      Spain  Raspberry and plum aromas lead to a jammy, pru...
#
#            designation  points  price         province  \
# 27                 NaN      81    5.0  Australia Other
# 3583   Abrazo del Toro      85    5.0   Northern Spain
# 4321               NaN      83    5.0  Australia Other
# 6381               NaN      84    5.0      Vinho Verde
# 14547          Crianza      81    5.0          Levante
#
#                       region_1 region_2             variety           winery  \
# 27     South Eastern Australia      NaN  Cabernet Sauvignon  Kelly's Revenge
# 3583                  Cariñena      NaN               Syrah           Abrazo
# 4321   South Eastern Australia      NaN          Chardonnay  Banrock Station
# 6381                       NaN      NaN                Rosé          Campelo
# 14547            Utiel-Requena      NaN         Tempranillo      Viña Decana
#
#        color continent  Good
# 27       red   Oceania     0
# 3583     red    Europe     0
# 4321   white   Oceania     0
# 6381   other    Europe     0
# 14547    red    Europe     0

# %%
#countries producing the most expensive wines

temp_expcountry_df = df.groupby("country")
# Calculates the average rating for each winery in a variable
exp_country = temp_expcountry_df["price"].median()
# Creates a new dataframe of just wineries and their average rating
exp_country_df = pd.DataFrame({"Avg Price" : exp_country})
exp_country_df
# Out:
#               Avg Price
# country
# Argentina          15.0
# Australia          20.0
# Austria            24.0
# Brazil             19.5
# Bulgaria            8.0
# Canada             28.0
# Chile              14.0
# China              27.0
# Croatia            19.0
# Cyprus             18.0
# France             29.0
# Georgia            11.5
# Germany            25.0
# Greece             19.0
# Hungary            17.5
# Israel             25.0
# Italy              30.0
# Lebanon            40.0
# Luxembourg         36.0
# Mexico             25.0
# Moldova            11.0
# New Zealand        20.0
# Portugal           18.0
# Romania            11.0
# Slovenia           22.5
# South Africa       18.0
# Spain              17.0
# Switzerland        19.0
# Turkey             23.0
# US                 28.0
# US-France          50.0
# Ukraine            13.0
# Uruguay            20.0

# %%
# finds the top 20 wineries by average rating
exp_20 = exp_country_df.sort_values("Avg Price").nlargest(20, "Avg Price").index.tolist()
# updates the dataframe to include only countries in the top 20 list
exp_country_df = exp_country_df[exp_country_df.index.isin(exp_20)]
exp_country_df.head()
# Out:
#            Avg Price
# country
# Australia       20.0
# Austria         24.0
# Brazil          19.5
# Canada          28.0
# China           27.0

# %%
exp_country_df.plot(kind='bar', title='Countries Producing the Most Expensive Wines', color='maroon')
plt.xlabel("Country")
plt.ylim(10,75)
plt.ylabel("Median Price of Wine Produced")
plt.figtext(0.5, -0.3, "Рисунок 13. - График распределения медианы цены в зависимости от страны " )
# Out:
# Text(0.5, -0.3, 'Рисунок 13. - График распределения медианы цены в зависимости от страны ')

# %%
#cheapest wine by country

temp_cheapcountry_df = df.groupby("country")
# Calculates the average rating for each winery in a variable
cheap_country = temp_cheapcountry_df["price"].median()
# Creates a new dataframe of just wineries and their average rating
cheap_country_df = pd.DataFrame({"Avg Price" : cheap_country})
# finds the top 20 wineries by average rating
cheapc_20 = cheap_country_df.sort_values("Avg Price").nsmallest(20, "Avg Price").index.tolist()
# updates the dataframe to include only countries in the top 20 list
cheap_country_df = cheap_country_df[cheap_country_df.index.isin(cheapc_20)]
cheap_country_df.head()
# Out:
#            Avg Price
# country
# Argentina       15.0
# Australia       20.0
# Brazil          19.5
# Bulgaria         8.0
# Chile           14.0

# %%
a = df[df.price <= 150][df.points <100]
sns.boxplot(x = 'points', y = 'price', data = a)
plt.figtext(0.5, -0.1, "Рисунок 14. - График зависимости рейтинга от цены" )
# Out:
# /tmp/ipython-input-68-2316766372.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   a = df[df.price <= 150][df.points <100]
# Text(0.5, -0.1, 'Рисунок 14. - График зависимости рейтинга от цены')

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.scatter(df["price"], df["points"], facecolors="red", edgecolors="black", alpha=.1)
plt.xlim(0, 300)
plt.title("Cost of Wine vs Ratings")
plt.xlabel("Cost (USD)")
plt.ylabel("Rating")
plt.figtext(0.5, -0.1, "Рисунок 14. - График зависимости цены от рейтинга" )
# Out:
# Text(0.5, -0.1, 'Рисунок 14. - График зависимости цены от рейтинга')

# %%
#Do more expensive wines have higher ratings?
fig, ax = plt.subplots(figsize=(20,10))
plt.scatter(df["price"], df["points"], facecolors="red", edgecolors="black")
plt.xlim(0, 3500)
plt.title("Cost of Wine vs Ratings")
plt.xlabel("Cost (USD)")
plt.ylabel("Rating")
plt.figtext(0.5, -0.1, "Рисунок 15. - График зависимости рейтинга от цены" )
plt.show()

#The below diagram shows that the most expensive wines are not the highest rated.
#Also, the most expensive wines are outliers.

# %%
df.designation.describe()
# Out:
# count       11637
# unique       7386
# top       Reserve
# freq          319
# Name: designation, dtype: object

# %%
df.designation.value_counts()
df.designation.value_counts()[:10]
# Out:
# designation
# Reserve           319
# Reserva           201
# Estate            197
# Barrel sample     175
# Barrel Sample      76
# Riserva            65
# Estate Grown       53
# Brut               50
# Estate Bottled     48
# Old Vine           39
# Name: count, dtype: int64

# %%
values_designation = df['designation'].value_counts()[:10].keys().tolist()
counts_designation = df['designation'].value_counts()[:10].tolist()

# %% [markdown]
# Признак винодельня

# %%
df.winery.describe()
# Out:
# count               16499
# unique               6396
# top       Williams Selyem
# freq                   55
# Name: winery, dtype: object

# %% [markdown]
# Количество виноделен использующих самое большое число сортов винограда

# %%
grapes = df[["winery", "variety"]].groupby(by = "winery").count()
max_num = max(grapes["variety"])
min_num = min(grapes["variety"])
max_num
# Out:
# 55

# %% [markdown]
# Сорта винограда Variety(Type of grape)

# %%
print('According to the dataset, there are {0} types of grapes'.format(df['variety'].nunique()))
# Out:
# According to the dataset, there are 32 types of grapes

# %%
V1= df[df.variety.isin(df.variety.value_counts().head(20).index)]

plt.figure(figsize = (14,6))
plt.title("Variety VS Points", fontsize=20)
sns.boxplot(
    x = 'variety',
    y = 'points',
    data = V1
)
plt.xticks(rotation = 90);

# %%
print('Number of varity of wines',df['variety'].nunique())
fig,ax = plt.subplots(1,2,figsize=(16,8))
ax1,ax2 = ax.flatten()

data_to_plot = df.groupby(['variety'])['price'].max().sort_values(ascending=False).to_frame()[:15]
sns.barplot(x = data_to_plot.price, y = data_to_plot.index, palette= 'spring',ax=ax1)
ax1.set_title('Виноград, из которого делают самое дорогое вино')
ax1.set_ylabel('Variety')
ax1.set_xlabel('')
data_to_plot = df.groupby(['variety'])['points'].max().sort_values(ascending=False).to_frame()[:15]
sns.barplot(x = data_to_plot.points, y = data_to_plot.index, palette = 'summer',ax=ax2)
ax2.set_title('Виноград, из которого делают самые качественные вина')
ax2.set_ylabel('')
ax2.set_xlabel('')
plt.subplots_adjust(wspace=0.3);
# Out:
# Number of varity of wines 32

# %%
plt.figure(figsize=(18,9))
Winery=df[df['winery']!='unknown']
WineryCnt=Winery['winery'].value_counts()
w = WineryCnt.head(20).plot.bar()
w.set_title("winery Of Wine Origin", fontsize=20)
w.set_xlabel("winery", fontsize=15)
w.set_ylabel("Counts", fontsize=15)
# Out:
# Text(0, 0.5, 'Counts')

# %% [markdown]
# В тройку лучших виноделов входят виноделы и виноделы, Willims Selyem и DFJ Vinhos. Всем этим троим более 175 лет.

# %% [markdown]
# Определим самый популярный сорт вина по стране

# %%
df.groupby('country').variety.apply(lambda x:x.value_counts().nlargest(1))
# Out:
# country
# Argentina     Malbec                       284
# Australia     Shiraz                       173
# Austria       Grüner Veltliner             155
# Brazil        Sparkling Blend                2
# Bulgaria      Merlot                         4
# Canada        Riesling                      13
# Chile         Cabernet Sauvignon           170
# China         Chardonnay                     2
# Croatia       White Blend                    3
# Cyprus        Red Blend                      5
# France        Bordeaux-style Red Blend     613
# Georgia       White Blend                    2
# Germany       Riesling                     316
# Greece        Red Blend                     22
# Hungary       Shiraz                         2
# Israel        Cabernet Sauvignon            24
# Italy         Red Blend                    463
# Lebanon       White Blend                    2
# Luxembourg    Riesling                       1
# Mexico        Red Blend                      3
# Moldova       Red Blend                      4
# New Zealand   Sauvignon Blanc              144
# Portugal      Portuguese Red               295
# Romania       Pinot Noir                     5
# Slovenia      White Blend                    2
# South Africa  Sauvignon Blanc               44
# Spain         Tempranillo                  271
# Switzerland   Merlot                         1
# Turkey        Red Blend                      4
# US            Pinot Noir                  1405
# US-France     Viognier                       1
# Ukraine       Sparkling Blend                1
# Uruguay       Red Blend                      3
# Name: variety, dtype: int64

# %% [markdown]
# #  <a name="3">3. Составление структуры развития рынка вина регионов</a>

# %% [markdown]
# * Самые популярные сорта (топ-5).
# * Влияет ли рейтинг на цены по регионам?

# %% [markdown]
# #  <a name="4"> 4. Исследование статистических показателей зависимости цены вина от рейтинга в регионе.</a>

# %% [markdown]
# Построить линейную регрессию зависимости между ценой продукта и его рейтингом.

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
y = df['price']

# Define the independent variable to be the SAT score
x1 = df['points']

# %%
plt.scatter(x1,y)
plt.xlabel('Рейтинг')
plt.ylabel('Цена')
# Out:
# Text(0, 0.5, 'Цена')

# %%
# y=b0+b1x1

x=sm.add_constant(x1)

results=sm.OLS(y,x).fit()
#Contain Ordinary Least Square Regression
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                         nan
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Tue, 15 Jul 2025   Prob (F-statistic):                nan
# Time:                        07:53:07   Log-Likelihood:                    nan
# No. Observations:               16499   AIC:                               nan
# Df Residuals:                   16497   BIC:                               nan
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const             nan        nan        nan        nan         nan         nan
# points            nan        nan        nan        nan         nan         nan
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                     nan
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                  nan
# Skew:                             nan   Prob(JB):                          nan
# Kurtosis:                         nan   Cond. No.                     2.35e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.35e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
sns.regplot(x="price", y="points", data=df)
# Out:
# <Axes: xlabel='price', ylabel='points'>

# %%
my_data = df.drop(df[df.price > 300].index)
my_data.shape
# Out:
# (16462, 13)

# %%
sns.regplot(x="points", y="price", data=my_data)
plt.xlim(75,100)
# Out:
# (75.0, 100.0)

# %% [markdown]
# Существует корреляция между точками, данными вину, и логорифмом цены вина. Линейная комбинация переменных может дать прямую линию, но эта линия не соответствует данным. Но одна из тенденций заключается в том, что чем больше очков, тем больше цена вина. Чтобы увидеть связь между двумя количественными переменными, я выбрал точечную диаграмму. График использует точки в качестве отметки для представления корреляции и позицию в качестве канала для репрезентации тренда.

# %%
fig = plt.figure(figsize=(20,15))
xx = np.log(df.price)
yy = df.points
plt.scatter(xx,yy)
plt.xlabel('log(Price)', fontsize=20)
plt.ylabel('Points', fontsize=20)
plt.title('Корелляция между Points и Price',fontsize=20)
plt.figtext(0.5, 0, "Рисунок 8. - График корелляция между Points и Price" )
# Out:
# Text(0.5, 0, 'Рисунок 8. - График корелляция между Points и Price')

# %% [markdown]
# #  <a name="5">5. Проверка гипотез </a>

# %% [markdown]
# * H0: Средние пользовательские рейтинги красного и белого вина одинаковые.
# * H1:Средние пользовательские рейтинги красного и белого вина разные.
#
# - Самостоятельно сформулировать и проверить гипотезу
#
#
# * Задать самостоятельно пороговое значение *alpha*.

# %%
# Two sample t test to check whether mean of charges in male significantly differ from mean of charges in female
Ho = "Рейтинг на вино производства Франции и на вино производства Италии одинаковы"   # Stating the Null Hypothesis
Ha = "Рейтинг на вино производства Франции и на вино производства Италии различны"   # Stating the Alternate Hypothesis
t = df[df.country == 'France']
g= df[df.country == 'Italy']
x = np.array(t[t.price < 200 ].points)  # Selecting charges corresponding to smokers as an array
y = np.array(g[g.price < 200].points) # Selecting charges corresponding to non-smokers as an array

# %%
from scipy import stats

# %%
results = stats.levene(x, y)

alpha = 0.05

print(results.pvalue)

if (results.pvalue < alpha):
    print('Отклонить гипотезу о равенстве дисперсий')
else:
    print('Принять гипотезу о равенстве дисперсий')
# Out:
# 0.0004351375415579956
# Отклонить гипотезу о равенстве дисперсий

# %%
t,p_value  = stats.ttest_ind(x,y, axis = 0, equal_var=False)

if p_value < 0.05:
    print(f'{Ha} так как p value - {p_value.round(3)} < 0.05')
else:
    print(f'{Ho} так как p value - {p_value.round(3)} > 0.05')
# Out:
# Рейтинг на вино производства Франции и на вино производства Италии одинаковы так как p value - 0.182 > 0.05

# %% [markdown]
# # <a name="6">6. Выводы</a>

# %% [markdown]
# **<center>Список литературы</center>**

# %% [markdown]
# **Нормативные правовые акты:**
# 1.	Профессиональный стандарт «Специалист по большим данным» утверждён приказом Министерства труда и социальной защиты Российской Федерации от 6 июля 2020 г. № 405н.
#
# **Учебники и учебные пособия:**
# 1.	Андерсон. К., Аналитическая культура: от сбора данных до бизнес-результатов. - Москва : Манн, Иванов и Фербер, 2017.
# 2.	Нисчал Н., Python – это просто. Пошаговое руководство по программированию и анализу данных. — СПб.: БХВ-Петербург, 2021.
# 3.	Мэтиз Э., Изучаем Python. Программирование игр, визуализация данных, веб-приложения. — СПб.: Питер, 2021.
# 4.	Пасхавер Б., Pandas в действии. — СПб.: Питер, 2023.
# 5.	Плас Дж. Вандер., Python для сложных задач: наука о данных — СПб.: Питер, 2024.
# 6.	Уилке К., Основы визуализации данных. Пособие по эффективной и убедительной подаче информации.— М.: Эксмо, 2024.
#
# **Электронные ресурсы:**
# 1.	PEP 8 – руководство по стилю для кода Python [Электронный ресурс]: URL: https://peps.python.org/pep-0008/ ((дата обращения: 07.07.2025).
# 2.	Сайт Python Academy [Электронный ресурс]: URL: https://www.python-academy.com/ (дата обращения: 05.07.2025).
