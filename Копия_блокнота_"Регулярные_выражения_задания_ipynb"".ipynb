# %% [markdown]
# #**Регулярные выражения**
#
# **Регулярные выражения** (regular expression, regex, регулярка) – это мощный способ обработки текста, позволяющий находить в строках подстроки по сложным условиям.
#
# Чуть более формально, регулярное выражение — это строка, задающая шаблон поиска подстрок в тексте. Одному шаблону может соответствовать много разных строк. Регулярное выражение состоит из обычных символов и специальных командных последовательностей. Например, \d задаёт любую цифру, а \d+ — задает любую последовательность из одной или более цифр.
#
# Работа с регулярными выражениями реализована во всех современных языках программирования. Однако существует несколько диалектов, поэтому функционал регулярных выражений может различаться от языка к языку.
#
# 📌Например, можно понять, какие даты в наборе строк представлены в формате DD/MM/YYYY, а какие - в других форматах.
#
# Или бывает, например, что перед работой с текстом, надо почистить его от своеобразного мусора: упоминаний пользователей, url и так далее.
#
# Навык полезный, давайте в нём тоже потренируемся.
#
# Для работы с регулярными выражениями есть библиотека **re**

# %%
import re

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Регулярные выражения обычно применяют для:
#
# - поиска подстрок в строке
# - разделения строки на подстроки
# - замены части строки

# %%
https://www.w3schools.com/python/python_regex.asp
# Out:
#   File "<ipython-input-1-3d6fc2b1fb15>", line 1
#     https://www.w3schools.com/python/python_regex.asp
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ##🔍 **Основные функции re**

# %% [markdown]
# | Функция         | Описание                                                     |
# | --------------- | ------------------------------------------------------------ |
# | `re.search()`   | Ищет **первое совпадение** в строке                          |
# | `re.match()`    | Проверяет **начало строки**                                  |
# | `re.findall()`  | Возвращает **все совпадения**                                |
# | `re.finditer()` | Итератор по всем совпадениям                                 |
# | `re.sub()`      | Заменяет совпадения                                          |
# | `re.split()`    | Разбивает строку по шаблону                                  |
# | `re.compile()`  | Создаёт объект регулярного выражения (для переиспользования) |

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print('\\')
# Out:
# \

# %%
print(r'\\привет мир')
# Out:
# \\привет мир

# %%
import re

pattern = r"\b\w{3}\b"
text = "Hello, how, are you?"

result = re.findall(pattern, text)
print(result)  # ['how', 'are', ‘you’]
# Out:
# ['how', 'are', 'you']

# %% [markdown]
# ##📚 **Классы символов**

# %% [markdown]
# | Шаблон | Значение             |
# | ------ | -------------------- |
# | `\d`   | Цифра `[0-9]`        |
# | `\D`   | Не цифра             |
# | `\w`   | Буква, цифра или `_` |
# | `\W`   | Всё, кроме `\w`      |
# | `\s`   | Пробельный символ    |
# | `\S`   | Не пробел            |

# %% [markdown]
# ##🔠 **Специальные символы**

# %% [markdown]
# | Символ   | Значение                                         |
# | -------- | ------------------------------------------------ |
# | `.`      | Любой символ, кроме `\n`                         |
# | `^`      | Начало строки                                    |
# | `$`      | Конец строки                                     |
# | `*`      | 0 или больше повторений                          |
# | `+`      | 1 или больше повторений                          |
# | `?`      | 0 или 1 повторение (или "ленивый" квантификатор) |
# | `{n}`    | Ровно `n` повторений                             |
# | `{n,}`   | `n` или больше                                   |
# | `{n,m}`  | от `n` до `m`                                    |
# | `[...]`  | Любой символ из набора                           |
# | `[^...]` | Любой символ **кроме**                           |
# | `\`      | Экранирование спецсимволов                       |

# %%
print('\\привет мир')
# Out:
# \привет мир

# %%
print(r'\\привет мир')
# Out:
# \\привет мир

# %% [markdown]
# ##🎯**Примеры**

# %%
# Поиск email
re.findall(r'\b\w+@\w+\.\w+\b', 'my email is test@mail.com и ghg@bnj.de')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2b52711e2872> in <cell line: 0>()
#       1 # Поиск email
# ----> 2 re.findall(r'\b\w+@\w+\.\w+\b', 'my email is test@mail.com и ghg@bnj.de')
#
# NameError: name 're' is not defined

# %%
# Поиск email
re.findall(r'\b\w+@\w+\.\w+\b', 'my email is test@mail.com')
# ['test@mail.com']

# %%
# Проверка номера телефона
re.match(r'^\d{3}-\d{2}-\d{2}$', '139-45-67')
# Out:
# <re.Match object; span=(0, 9), match='139-45-67'>

# %%
# Замена всех цифр на X
re.sub(r'\d', 'X', 'phone: 123-45-67')
# 'phone: XXX-XX-XX'
# Out:
# N
# 'phone: NNN-NN-NN'

# %%
import re

text = '123-45-67'
pattern = r'^\d{3}-\d{2}-\d{2}$'

match =re.match(pattern, text)
if match:
    print("Совпадение найдено:", match.group())
else:
    print("Совпадение не найдено")
# Out:
# Совпадение найдено: 123-45-67

# %%
import re

text = "Python 3.9, Java 17, C++ 14"

numbers = re.findall(r"\d+", text)  # Поиск всех чисел
print(numbers)
# Out:
# ['3', '9', '17', '14']

# %%
import re

text = "Python 3.9, Java 17, C++ 14 1920 54739"

numbers = re.findall(r"\d{2}+", text)  # Поиск всех чисел
print(numbers)
# Out:
# ['17', '14', '19', '20', '54', '73']

# %%
text = "\tPython 3.12, Java 17, C++ 14!\n"
print(text)
# Out:
# 	Python 3.12, Java 17, C++ 14!

# %%
text = "\tPython 3.12, Java 17, C++ 14!\n"

print("Цифры:", re.findall(r"\d", text))
print("Двузначные цифры:", re.findall(r"\d\d", text))
# Out:
# Цифры: ['3', '1', '2', '1', '7', '1', '4']
# Двузначные цифры: ['12', '17', '14']

# %%
print("НЕ цифры:", re.findall(r"\D", text))

print("Буквы, цифры, _:", re.findall(r"\w", text))

print("НЕ буквы, цифры, _:", re.findall(r"\W", text))
# Out:
# НЕ цифры: ['\t', 'P', 'y', 't', 'h', 'o', 'n', ' ', '.', ',', ' ', 'J', 'a', 'v', 'a', ' ', ',', ' ', 'C', '+', '+', ' ', '!', '\n']
# Буквы, цифры, _: ['P', 'y', 't', 'h', 'o', 'n', '3', '1', '2', 'J', 'a', 'v', 'a', '1', '7', 'C', '1', '4']
# НЕ буквы, цифры, _: ['\t', ' ', '.', ',', ' ', ' ', ',', ' ', '+', '+', ' ', '!', '\n']

# %%
print("Пробелы:", re.findall(r"\s", text))

print("НЕ пробелы:", re.findall(r"\S", text))

print("Все символы (кроме \\n):", re.findall(r".", text))
# Out:
# Пробелы: ['\t', ' ', ' ', ' ', ' ', ' ', '\n']
# НЕ пробелы: ['P', 'y', 't', 'h', 'o', 'n', '3', '.', '1', '2', ',', 'J', 'a', 'v', 'a', '1', '7', ',', 'C', '+', '+', '1', '4', '!']
# Все символы (кроме \n): ['\t', 'P', 'y', 't', 'h', 'o', 'n', ' ', '3', '.', '1', '2', ',', ' ', 'J', 'a', 'v', 'a', ' ', '1', '7', ',', ' ', 'C', '+', '+', ' ', '1', '4', '!']

# %%
text = "Report, report, report2, report10, mas"


print("Буквы r или R в слове:", re.findall(r"[rR]eport", text))

print("Все цифры:", re.findall(r"[0-9]", text))
# Out:
# Буквы r или R в слове: ['Report', 'report', 'report', 'report']
# Все цифры: ['2', '1', '0']

# %%
text = "Report, report, report2, report10"


print("Заглавные буквы:", re.findall(r"[A-Z]", text))

print("Строчные буквы:", re.findall(r"[a-z]", text))
# Out:
# Заглавные буквы: ['R']
# Строчные буквы: ['e', 'p', 'o', 'r', 't', 'r', 'e', 'p', 'o', 'r', 't', 'r', 'e', 'p', 'o', 'r', 't', 'r', 'e', 'p', 'o', 'r', 't']

# %%
print("Все буквы:", re.findall(r"[a-zA-Z]", text))

print("Все, кроме цифр:", re.findall(r"[^0-9]", text))
# Out:
# Все буквы: ['R', 'e', 'p', 'o', 'r', 't', 'r', 'e', 'p', 'o', 'r', 't', 'r', 'e', 'p', 'o', 'r', 't', 'r', 'e', 'p', 'o', 'r', 't']
# Все, кроме цифр: ['R', 'e', 'p', 'o', 'r', 't', ',', ' ', 'r', 'e', 'p', 'o', 'r', 't', ',', ' ', 'r', 'e', 'p', 'o', 'r', 't', ',', ' ', 'r', 'e', 'p', 'o', 'r', 't']

# %%
import re

# %%
text = """
Orders: 6 ID123, ID4567, ID89
Numbers: 123-45-67, 321-45-67
Prices: 100$, 199.50$, 99.99€, 0.49€, .99€
File names: report.txt, report2.txt, report10.txt
"""

print("Одна или более цифр:", re.findall(r"\d+", text))

print("Телефонные номера (формата xxx-xx-xx):", re.findall(r"\d{3}-\d{2}-\d{2}", text))
# Out:
# Одна или более цифр: ['6', '123', '4567', '89', '123', '45', '67', '321', '45', '67', '100', '199', '50', '99', '99', '0', '49', '99', '2', '10']
# Телефонные номера (формата xxx-xx-xx): ['123-45-67', '321-45-67']

# %%
print("Цены (числа с десятичной точкой):", re.findall(r"\d+\.\d+", text))

print("ID-коды:", re.findall(r"ID\d{2,}", text))
# Out:
# Цены (числа с десятичной точкой): ['199.50', '99.99', '0.49']
# ID-коды: ['ID123', 'ID4567', 'ID89']

# %%
print("Имена файлов 0+ цифр:", re.findall(r"report\d*.txt", text))

print("Имена файлов 0/1 цифр:", re.findall(r"report\d?.txt", text))

print("Имена файлов 1/2 цифр:", re.findall(r"report\d{1,2}.txt", text))
# Out:
# Имена файлов 0+ цифр: ['report.txt', 'report2.txt', 'report10.txt']
# Имена файлов 0/1 цифр: ['report.txt', 'report2.txt']
# Имена файлов 1/2 цифр: ['report2.txt', 'report10.txt']

# %%
text = "<div>Hello</div><div>World</div>"

greedy = re.findall(r"<.*>", text)  # Жадный
lazy = re.findall(r"<.*?>", text)   # Ленивый

print(greedy)
print(lazy)
# Out:
# ['<div><a>Hello</div><div>World</div>']
# ['<div>', '<a>', '</div>', '<div>', '</div>']

# %%
text = "report.txt, report2.txt, report10.txt, some_txt_report, some_report_txt, reports\\report.txt, report2.txt"

print("Имена файлов с txt:", re.findall(r"\w+.txt", text))

# Имена файлов с расширением .txt
print("Имена файлов с расширением .txt:", re.findall(r"\w+\.txt", text))

# Имена файлов в папке
print("Имена файлов в папке:", re.findall(r"\w+\\\w+\.\w+", text))
# Out:
# Имена файлов с txt: ['report.txt', 'report2.txt', 'report10.txt', 'some_txt', 'some_report_txt', 'report.txt', 'report2.txt']
# Имена файлов с расширением .txt: ['report.txt', 'report2.txt', 'report10.txt', 'report.txt', 'report2.txt']
# Имена файлов в папке: ['reports\\report.txt']

# %%
text = "Hello world! Welcome to world"

print("Слово в начале строки:", re.findall(r"^\w+", text))
print("Слово в конце строки:", re.findall(r"\w+$", text))
# Out:
# Слово в начале строки: ['Hello']
# Слово в конце строки: ['world']

# %%
text2 = "category wildcat education _cat_ catalog cat"

print("Слова с 'cat' внутри:", re.findall(r"\w+cat\w+", text2))
print("Слова с 'cat' в начале слов:", re.findall(r"\bcat\w*", text2))
print("Слова с 'cat' в конце слов:", re.findall(r"\w*cat\b", text2))
# Out:
# Слова с 'cat' внутри: ['education', '_cat_']
# Слова с 'cat' в начале слов: ['category', 'catalog', 'cat']
# Слова с 'cat' в конце слов: ['wildcat', 'cat']

# %%
text3 = "X123X 234 4567X X999"
print("Числа внутри строк:", re.findall(r"\B\d+\B", text3))
# Out:
# Числа внутри строк: ['123', '3', '567', '99']

# %%
text = "Order ID: 12345, Invoice No: 67890"

# Найдём ID заказа и счёта
match = re.search(r"Order ID: (\d+), Invoice No: (\d+)", text)

if match:
    print("ID заказа:", match.group(1))
    print("Номер счёта:", match.group(2))
# Out:
# ID заказа: 12345
# Номер счёта: 67890

# %%
text = "USD 100, EUR 200, GBP 300"

# Найдём суммы, не выделяя валюту
matches = re.findall(r"(?:USD|EUR|GBP) (\d+)", text)
print("Суммы:", matches)

# Найдём суммы и валюту
matches = re.findall(r"(USD|EUR|GBP) (\d+)", text)
print("Суммы:", matches)
# Out:
# Суммы: ['100', '200', '300']
# Суммы: [('USD', '100'), ('EUR', '200'), ('GBP', '300')]

# %%
text = "ID12345 is confirmed. ID23456 is confirmed"

# Проверяем, начинается ли строка с "ID" + цифры
match = re.match(r"ID\d+", text)

if match:
    print("Объект Match:", match)
    print("Само совпадение:", match.group())
    print("Диапазон совпадения:", match.span())
else:
    print("Нет совпадения.")
# Out:
# Объект Match: <re.Match object; span=(0, 7), match='ID12345'>
# Само совпадение: ID12345
# Диапазон совпадения: (0, 7)

# %%
text = "Order ID: 12345, Invoice No: 67890, Ref: ABC9876"

# Найдём первое число в тексте
match = re.search(r"\d+", text)

if match:
    print("Объект Match:", match)
    print("Само совпадение:", match.group())
    print("Индекс начала:", match.start())
    print("Индекс конца:", match.end())
    print("Диапазон совпадения:", match.span())
else:
    print("Нет совпадения.")
# Out:
# Объект Match: <re.Match object; span=(10, 15), match='12345'>
# Само совпадение: 12345
# Индекс начала: 10
# Индекс конца: 15
# Диапазон совпадения: (10, 15)

# %%
text = "Order ID: 12345, Invoice No: 67890, Ref: ABC9876"

# Найдём первое число в тексте
match = re.findall(r"\d+", text)

if match:
    print("Объект Match:", match)

else:
    print("Нет совпадения.")
# Out:
# Объект Match: ['12345', '67890', '9876']

# %%
text = "Order ID: 12345, Invoice No: 67890, Ref: ABC9876"

# Найдём все числа в тексте
matches = re.finditer(r"\d+", text)

for match in matches:
    print("Объект Match:", match)
    print("Само совпадение:", match.group())
    print("Диапазон совпадения:", match.span())
    print()
# Out:
# Объект Match: <re.Match object; span=(10, 15), match='12345'>
# Само совпадение: 12345
# Диапазон совпадения: (10, 15)
#
# Объект Match: <re.Match object; span=(29, 34), match='67890'>
# Само совпадение: 67890
# Диапазон совпадения: (29, 34)
#
# Объект Match: <re.Match object; span=(44, 48), match='9876'>
# Само совпадение: 9876
# Диапазон совпадения: (44, 48)

# %% [markdown]
# #**Практическое задание 1**

# %%
import re

def validate_password(password):
    # Проверка длины пароля
    if len(password) < 8:
        return False

    # Проверка наличия хотя бы одной заглавной буквы
    if not re.search(r'[A-Z]', password):
        return False

    # Проверка наличия хотя бы одной строчной буквы
    if not re.search(r'[a-z]', password):
        return False

    # Проверка наличия хотя бы одной цифры
    if not re.search(r'[0-9]', password):
        return False

    # Проверка на допустимые специальные символы
    if not re.fullmatch(r'[A-Za-z0-9!@#$%^&*()]*', password):
        return False

    return True

# %% [markdown]
# #**Практическое задание 2**

# %%
import re

text = "Server1: 192.168.1.1, Server2: 10.0.0.254, Invalid: 999.123.456.78"

# Регулярное выражение для поиска IPv4-адресов
ip_pattern = r'\b(25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?)\.(25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?)\.(25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?)\.(25[0-5]|2[0-4][0-9]|[01]?[0-9][0-9]?)\b'

# Находим все совпадения
ip_addresses = re.findall(ip_pattern, text)

# Преобразуем кортежи в строки с точками
valid_ips = ['.'.join(ip) for ip in ip_addresses]

# Выводим результат
for ip in valid_ips:
    print(ip)
# Out:
# 192.168.1.1
# 10.0.0.254

# %%
import re

text = '123-45-67'
pattern = r'\b\w+@\w+\.\w+\b'

match =re.match(pattern, text)
if match:
    print("Совпадение найдено:", match.group())
else:
    print("Совпадение не найдено")

# %%
if
print(re.match(r'^\d{3}-\d{2}-\d{2}$', '123-45-67'))
# Out:
# <re.Match object; span=(0, 9), match='123-45-67'>

# %%
print(re.match(r'^\d{4}-\d{4}-\d{3}$', '1232-4522-672'))
# Out:
# <re.Match object; span=(0, 13), match='1232-4522-672'>

# %%
string = 'We can get 30 to 54 time faster code if we add about 340 lines of 368  code 390'
pattern = '3.0'
found = re.findall(pattern, string)
print(found)
# Out:
# ['340', '390']

# %%
import re
def CheckString(s):
    if re.search('ab+', s):
        return True
    else:
        return False
text = "a"
print(CheckString(text))
# Out:
# False

# %%
import re
def CheckString(s):
    if re.search('ab*', s):
        return True
    else:
        return False
text = "ab"
print(CheckString(text))
# Out:
# True

# %%
import re
def CheckString(s):
    if re.search('ab:?', s):
        return True
    else:
        return False
text = "abb"
print(CheckString(text))
# Out:
# True

# %%
import re

text = "colorrrr colourrr colurrr"
matches = re.findall(r'colou:?r', text)
print(matches)  # ['color', 'colour', 'colur']
# Out:
# ['colour']

# %%
import re

text = "colorrr colourrrr colurrrr"
matches = re.search(r'colou?r', text)
print(matches)  # ['color', 'colour', 'colur']
# Out:
# <re.Match object; span=(0, 5), match='color'>

# %% [markdown]
# #**Задачи**

# %% [markdown]
# Написать программу, которая использует функции языка для работы с регулярными выражениями и синтаксис регулярных выражений:
#
# 1. Определите, содержит ли заданная строка набор данных символов (a-z, A-Z и 0-9).
#
# 2. Определите, содержит ли строка символ ‘a’, за которым следует ноль или более символов ‘b’.
#
# 3. Определите, содержит ли строка символ ‘a’, за которым следует 1 или более символов ‘b’.
#
# 4. Определите, содержит ли строка символ ‘a’, за которым следует 0 или 1 символ ‘b’.
#
# 5. Определите, содержит ли строка символ z.

# %% [markdown]
# 6. Определите, содержит ли строка только буквы, цифры и символ подчеркивания.
#
# 7. Определите, начинается ли строка с заданного числа.
#
# 8. Напишите программу, которая удаляет нули (0) перед цифрами в IP адресе. Например, “192.01.001.10”  → “192.1.1.10”
#
# 9. Определите, содержит ли строка цифры в конце.
#
# 10. Найдите вхождения и позиции подстроки в строке. Пример: строка “Домашние задания, задания в классе, отпускные задания”, подстрока “задания”, вывод “задания” на 9:15, “задания” на 18:24, “задания” на 46:52.

# %% [markdown]
# 11. Напишите программу, которая заменяет пробелы подчеркиваниями и обратно.
#
# 12. Частью URL часто является дата в формате 2016/09/02. Например, https://www.somesite.com/news/2024/01/22/article.html. Найдите все даты в URL такого вида. Вывод может выглядеть так [('2024', '01', '22')].
#
# 13. Напишите программу, которая конвертирует дату в формате yyyy-mm-dd в формат dd-mm-yyyy.
#
# 14. Напишите программу, которая отделяет и печатает цифры в заданной строке. Например, для строки "Ten 10, Twenty 20, Thirty 30" должно быть выведено 10, 20, 30.
#
# 15. Напишите программу, которая выводит все слова, начинающиеся на букву ‘a’ и ‘e’ в заданном предложении.

# %% [markdown]
# 16. Напишите программу, которая печатает цифры и их позиции в заданной строке текста.
#
# 17. Напишите программу, которая сокращает Strasse на Str. в заданной строке, например, “Flensburger Strasse” → “Flensburger Str.”.
#
# 18. Напишите программу, которая заменяет все вхождения пробела, запятой или точки подчеркиванием.
#
# 19. Напишите программу, которая находит все слова длины 3 в заданном предложении.
#
# 20. Напишите программу, которая находит все слова длины 3, 4 и 5 символов в заданном предложении.

# %% [markdown]
# 21. Напишите программу, которая превращает camel-case строку в snake-case строку, например, “ПайтонПрограммист” -> “пайтон_программист”.
#
# 22. Напишите программу, которая выводит значения между кавычками в строке. Например, "Python", "PHP", "Java" -> [‘Python’, ‘PHP’, ‘Java’].
#
# 23. Напишите программу, которая удаляет несколько идущих подряд пробелов из строки, заменяя их одним пробелом. “Hello     World” -> “Hello World”.
#
# 24. Напишите программу, которая удаляет все пробелы из строки.
#
# 25. Напишите программу, которая заменяет в тексте все слова, начинающиеся на ‘х’ или ‘f’ на звездочки.

# %% [markdown]
# В регулярных выражениях, кроме привычных символов-букв, есть специальные символы:
# * **?а** - ноль или один символ **а**
# * **+а** - один или более символов **а**
# * **\*а** - ноль или более символов **а** (не путать с +)
# * **.** - любое количество любого символа
#
# Пример:
# Выражению \*a?b. соответствуют последовательности a, ab, abc, aa, aac НО НЕ abb!

# %% [markdown]
# Рассмотрим подробно несколько наиболее полезных функций:

# %% [markdown]
# ### findall
# возвращает список всех найденных непересекающихся совпадений.
#
# Регулярное выражение **ab+c.**:
# * **a** - просто символ **a**
# * **b+** - один или более символов **b**
# * **c** - просто символ **c**
# * **.** - любой символ

# %%
string = "«Генерал Слокам» 15 июня 1904 года Ист-Ривер Человеческий фактор"
print(re.search('\w+', string))
# Out:
# <re.Match object; span=(1, 8), match='Генерал'>

# %%
string = "«Генерал Слокам» 15 июня 1904 года Ист-Ривер Человеческий фактор"
print(re.search('\w+', string).group())
# Out:
# Генерал

# %%
string = "«78»«Генерал Слокам» 15 июня 1904 года  Ист-Ривер Человеческий фактор"
print(re.search('«[А-я ]+»', string).group())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-136cbfce7ec1> in <cell line: 0>()
#       1 string = "«78»«Генерал Слокам» 15 июня 1904 года  Ист-Ривер Человеческий фактор"
# ----> 2 print(re.search('«[А-я ]+»', string).group())
#
# NameError: name 're' is not defined

# %%
string = "«Генерал 2 Слокам» 15 июня 1904 года Ист-Ривер Человеческий фактор"
print(re.search('«[А-я ]+»', string))
# Out:
# None

# %%
import re
string = "«Генерал Слокам» 15 июня 1904 года Ист-Ривер Человеческий фактор"
print(re.split('\d+', string))
# Out:
# ['«Генерал Слокам» ', ' июня ', ' года Ист-Ривер Человеческий фактор']

# %%
import re
string = "«Генерал Слокам» 15 июня 1904 года Ист-Ривер Человеческий фактор"
print(re.split('\d+', string, maxsplit = 1))
# Out:
# ['«Генерал Слокам» ', ' июня 1904 года Ист-Ривер Человеческий фактор']

# %%
import re
string = "«Генерал Слокам» 15 июня 1904 года Ист-Ривер Человеческий фактор"
print(re.sub('\d+', '', string)) #ищем числа
# и заменяем на пустоту
# Out:
# «Генерал Слокам»  июня  года Ист-Ривер Человеческий фактор

# %%
import re
mya = "Вовремя подняли знамя и бросились в пламя"
print(re.findall('[А-я]+мя', mya))
# Out:
# ['Вовремя', 'знамя', 'пламя']

# %%
import re
string = "«Генерал Слокам» 15 &-&  5-9 июня 1904 года Ист-Ривер Человеческий фактор"
print(re.findall('\w+-\w+', string))
# Out:
# ['5-9', 'Ист-Ривер']

# %%
import re
string = "«Генерал Слокам» 15 июня 1904 !!! года Ист-Ривер Человеческий фактор"
print(re.findall('\w+', string))
print(len(re.findall('\w+', string)))
# Out:
# ['Генерал', 'Слокам', '15', 'июня', '1904', 'года', 'Ист', 'Ривер', 'Человеческий', 'фактор']
# 10

# %%
import re
string = "«Генерал Слокам» 15 июня 1904 года Ист-Ривер Человеческий фактор"
print(re.findall('[\w-]+', string))
print(len(re.findall('[\w-]+', string)))
# Out:
# ['Генерал', 'Слокам', '15', 'июня', '1904', 'года', 'Ист-Ривер', 'Человеческий', 'фактор']
# 9

# %% [markdown]
# Функция len() вывела результат на единицу больше, чем мы ожидали. Так произошло, потому что слово «Ист-Ривер» разбилось на два слова, ведь «-» не подходит под шаблон '\w+'.

# %% [markdown]
# 1.
# Напишите регулярное выражение для поиска в начале строки данных, которые содержат только буквы — английские или русские. Сохраните строку с выражением в переменной pattern и выведите её на экран.

# %%
string = "Генерал Слокам» 15 июня 1904 года Ист-Ривер Человеческий фактор"
pattern = '^[A-zА-я]+'
print(re.findall(pattern,  string))
# Out:
# ['Генерал']

# %%
string = "«Генерал Слокам» 15 июня 1904 года Ист-Ривер Человеческий фактор"
pattern = '^[A-zА-я]+'
print(re.findall(pattern,  string))
# Out:
# []

# %%
result = re.findall('ab+c.', 'abbcdefghijkabcabcabc')
print(result)
# Out:
# ['abbcd', 'abca']

# %% [markdown]
# Напишите регулярное выражение, которое выводит все названия продуктов, начинающихся со слова Масло

# %%
string='Кашу Маслом не испортишь,'
print(re.findall('Масло[^\d]+', string))
# Out:
# ['Маслом не испортишь,']

# %%
found_products = re.findall('Молоко[А-яA-z -]+', req_text)

# %% [markdown]
# Вопрос на внимательность: почему нет abcx?

# %% [markdown]
# **Задание**: вернуть список первых двух букв каждого слова в строке, состоящей из нескольких слов.

# %%
sent = 'hello world, I am Alina'.split()
for s in sent:
  print(re.findall('\w{2}',s))
#result=re.findall('\w{2}','hello world')
#result
# Out:
# ['he', 'll']
# ['wo', 'rl']
# []
# ['am']
# ['Al', 'in']

# %% [markdown]
# ### split
# разделяет строку по заданному шаблону

# %%
result = re.split(',', 'itsy, bitsy, teenie, weenie')
print(result)
# Out:
# ['itsy', ' bitsy', ' teenie', ' weenie']

# %% [markdown]
# можно указать максимальное количество разбиений

# %%
result = re.split(',', 'itsy, bitsy, teenie, weenie', maxsplit=2)
print(result)
# Out:
# ['itsy', ' bitsy', ' teenie, weenie']

# %% [markdown]
# **Задание**: разбейте строку, состоящую из нескольких предложений, по точкам, но не более чем на 3 предложения.

# %% [markdown]
# ### sub
# ищет шаблон в строке и заменяет все совпадения на указанную подстроку
#
# параметры: (pattern, repl, string)

# %%
result = re.sub('a', 'b', 'abcabc')
print (result)
# Out:
# bbcbbc

# %% [markdown]
# **Задание**: напишите регулярное выражение, которое позволит заменить все цифры в строке на "DIG".

# %% [markdown]
# **Задание**: напишите  регулярное выражение, которое позволит убрать url из строки.

# %% [markdown]
# ### compile
# компилирует регулярное выражение в отдельный объект

# %%
# Пример: построение списка всех слов строки:
prog = re.compile('[А-Яа-яё\-]+')
prog.findall("Слова? Да, больше, ещё больше слов! Что-то ещё.")
# Out:
# ['Слова', 'Да', 'больше', 'ещё', 'больше', 'слов', 'Что-то', 'ещё']

# %% [markdown]
# **Задание**: для выбранной строки постройте список слов, которые длиннее трех символов.

# %% [markdown]
# **Задание**: вернуть список доменов (@gmail.com) из списка адресов электронной почты:
#
# ```
# abc.test@gmail.com, xyz@test.in, test.first@analyticsvidhya.com, first.test@rest.biz
# ```

# %% [markdown]
# Если всё ещё осталось время: [регулярочный кроссворд ¯\_(ツ)_/¯](https://mariolurig.com/crossword/)
